# %%
import torch
import torchvision as tv
import torch.nn as nn
from torch.nn import functional as F
import time
from PIL import Image
import PIL
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os
import random
from torchsummary import summary as model_summary
import glob
import nibabel as nib
import skimage
import sklearn
from sklearn import model_selection
import monai

from monai.networks.nets import UNet
from monai.networks.layers import Norm
from monai.transforms import (
    Compose,
    EnsureChannelFirstd,
    LoadImage,
    LoadImaged,
    Orientationd,
    Rand3DElasticd,
    RandAffined,
    Spacingd,
    Resized,
    NormalizeIntensityd,
    ToTensord,
    AsDiscrete,
)
from monai.config import print_config
from typing import Optional

from tqdm import tqdm
# from tqdm.notebook import tqdm

print(f'torch.cuda.is_available(): {torch.cuda.is_available()}')
print(f'torch.cuda.get_device_name(0): {torch.cuda.get_device_name(0)}')
print(f'torch.version.cuda: {torch.version.cuda}')
print(f'torch.cuda.device_count(): {torch.cuda.device_count()}')
print()
monai.config.print_config()
# Out:
# torch.cuda.is_available(): True
# torch.cuda.get_device_name(0): NVIDIA GeForce RTX 3060
# torch.version.cuda: 11.3
# torch.cuda.device_count(): 1
#
# MONAI version: 1.0.0
# Numpy version: 1.22.3
# Pytorch version: 1.12.1
# MONAI flags: HAS_EXT = False, USE_COMPILED = False, USE_META_DICT = False
# MONAI rev id: 170093375ce29267e45681fcec09dfa856e1d7e7
# MONAI __file__: /home/kimbg/anaconda3/envs/test1/lib/python3.10/site-packages/monai/__init__.py
#
# Optional dependencies:
# Pytorch Ignite version: NOT INSTALLED or UNKNOWN VERSION.
# Nibabel version: 4.0.2
# scikit-image version: 0.19.3
# Pillow version: 9.2.0
# Tensorboard version: NOT INSTALLED or UNKNOWN VERSION.
# gdown version: NOT INSTALLED or UNKNOWN VERSION.
# TorchVision version: 0.13.1
# tqdm version: 4.64.0
# lmdb version: NOT INSTALLED or UNKNOWN VERSION.
# psutil version: 5.9.0
# pandas version: 1.5.1
# einops version: 0.5.0
# transformers version: NOT INSTALLED or UNKNOWN VERSION.
# mlflow version: NOT INSTALLED or UNKNOWN VERSION.
# pynrrd version: NOT INSTALLED or UNKNOWN VERSION.
#
# For details about installing the optional dependencies, please visit:
#     https://docs.monai.io/en/latest/installation.html#installing-the-recommended-dependencies

# %% [markdown]
# ## 구성
# 1. 데이터 불러오기
# 2. 데이터 체크(형태, 구조, 자료형 확인)
# 3. 데이터 전처리
#     - minmax
#     - resize 등
# 4. 2번 다시
# 5. 시각화

# %%
### HYPER PARAMETER ###

RANDOM_SEED = 831
IMAGE_SIZE = (128, 128, 128)
BATCH_SIZE = 2
NUM_CLASS = 2
EPOCHS = 200
test_ratio, val_ratio = 0.1, 0.2

MODEL_SAVE = False
if MODEL_SAVE:
    model_dir1 = '/data/MODEL_BG/'
    model_dir2 = 'Segmentation(3D)-UNETR(bg)'
    MODEL_SAVE_PATH = os.path.join(model_dir1, model_dir2)
    os.makedirs(MODEL_SAVE_PATH, exist_ok=True)
    
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# DEVICE = 'cpu'

# %% [markdown]
# 0. 데이터 준비
# - 데이터가 있으면 `data_dir`를 자신의 경로에 맞게 수정해주세요.
# - 데이터가 없으면 `USE_MY_DATA` 를 `False`로 두고 다운로드 받으면 됩니다.
# - The dataset comes from http://medicaldecathlon.com/.

# %%
USE_MY_DATA = True

if not USE_MY_DATA:
    directory = os.environ.get("MONAI_DATA_DIRECTORY")
    root_dir = tempfile.mkdtemp() if directory is None else directory
    print(f"root dir is: {root_dir}")
    
    resource = "https://msd-for-monai.s3-us-west-2.amazonaws.com/Task09_Spleen.tar"
    md5 = "410d4a301da4e5b2f6f86ec3ddba524e"

    compressed_file = os.path.join(root_dir, "Task09_Spleen.tar")
    data_dir = os.path.join(root_dir, "Task09_Spleen")
    if not os.path.exists(data_dir):
        download_and_extract(resource, compressed_file, root_dir, md5)

else:
    data_dir = '/data/MSD/Task09_Spleen'

# %%
train_images = sorted(
    glob.glob(os.path.join(data_dir, "imagesTr", "*.nii.gz")))
train_labels = sorted(
    glob.glob(os.path.join(data_dir, "labelsTr", "*.nii.gz")))
data_dicts = [
    {"image": image_name, "label": label_name}
    for image_name, label_name in zip(train_images, train_labels)
]
train_data_dicts, val_data_dicts = data_dicts[:-9], data_dicts[-9:]
train_data_dicts[0]
# Out:
# {'image': '/data/MSD/Task09_Spleen/imagesTr/spleen_10.nii.gz',
#  'label': '/data/MSD/Task09_Spleen/labelsTr/spleen_10.nii.gz'}

# %% [markdown]
# 1. 데이터 불러오기

# %%
train_images = sorted(
    glob.glob(os.path.join(data_dir, "imagesTr", "*.nii.gz")))
train_labels = sorted(
    glob.glob(os.path.join(data_dir, "labelsTr", "*.nii.gz")))

data_dicts = [
    {"image": image_name, "label": label_name}
    for image_name, label_name in zip(train_images, train_labels)
]

TrainSet, TestSet = model_selection.train_test_split(data_dicts, test_size=test_ratio, random_state=RANDOM_SEED)
TrainSet, ValSet = model_selection.train_test_split(TrainSet, test_size=val_ratio, random_state=RANDOM_SEED)
print('TrainSet:', len(TrainSet), 'ValSet:', len(ValSet), 'TestSet:', len(TestSet))
# Out:
# img cnt: 41 ['/data/MSD/Task09_Spleen/imagesTr/spleen_10.nii.gz']
# mask cn:; 41 ['/data/MSD/Task09_Spleen/labelsTr/spleen_10.nii.gz']
# TrainSet: 28 ValSet: 8 TestSet: 5

# %% [markdown]
# 2. 데이터 체크(형태, 구조, 자료형 확인)

# %%
for i in range(3):
    sample_img = nib.load(TrainSet[i]['image']).get_fdata()
    sample_mask = nib.load(TrainSet[i]['label']).get_fdata()
    print(f"[sample {i+1}] {os.path.basename(TrainSet[i]['image'])} {os.path.basename(TrainSet[i]['label'])}")
    print(sample_img.shape, sample_img.dtype, np.min(sample_img), np.max(sample_img))
    print(sample_mask.shape, sample_mask.dtype, np.unique(sample_mask))
# Out:
# [sample 1] spleen_2.nii.gz spleen_2.nii.gz
# (512, 512, 90) float64 -1024.0 3071.0
# (512, 512, 90) float64 [0. 1.]
# [sample 2] spleen_19.nii.gz spleen_19.nii.gz
# (512, 512, 51) float64 -1024.0 1372.0
# (512, 512, 51) float64 [0. 1.]
# [sample 3] spleen_17.nii.gz spleen_17.nii.gz
# (512, 512, 95) float64 -1024.0 1964.0
# (512, 512, 95) float64 [0. 1.]

# %% [markdown]
# 3. 데이터 전처리
#     - minmax
#     - resize 등

# %%
from monai.transforms.compose import Transform, MapTransform

class MinMax(MapTransform):
    def __init__(self, keys):
        super().__init__(keys)

    def __call__(self, data):
        d = dict(data)
        for key in self.keys:
            d[key] -= np.min(d[key])
            d[key] /= np.max(d[key])
        return d

loader = LoadImaged(keys=("image",'label'), image_only=False)
ensure_channel_first = EnsureChannelFirstd(keys=["image",'label'])
orientation = Orientationd(keys=["image",'label'], axcodes="RAS")
resize_img = Resized(keys=["image",], spatial_size=(IMAGE_SIZE), mode='trilinear')
resize_mask = Resized(keys=['label',], spatial_size=(IMAGE_SIZE), mode='nearest-exact')
# normalize = NormalizeIntensityd(keys=["image",])
minmax = MinMax(keys=['image',])

# %% [markdown]
# 2. 데이터 체크(형태, 구조, 자료형 확인)

# %%
transforms = Compose([
    LoadImaged(keys=("image",'label'), image_only=False),
    EnsureChannelFirstd(keys=["image",'label']),
    Orientationd(keys=["image",'label'], axcodes="RAS"),
    Resized(keys=["image",], spatial_size=(IMAGE_SIZE), mode='trilinear'),
    Resized(keys=['label',], spatial_size=(IMAGE_SIZE), mode='nearest-exact'),
    # normalize = NormalizeIntensityd(keys=["image",])
    MinMax(keys=['image',]),
    ToTensord(keys=["image", "label"]),
    ])

SampleSet = transforms(TestSet[:3])

for i in range(3):
    sample_img = SampleSet[i]['image']
    sample_mask = SampleSet[i]['label']
    print(f"[sample {i+1}]")
    print(sample_img.shape, sample_img.dtype, torch.min(sample_img), torch.max(sample_img))
    print(sample_mask.shape, sample_mask.dtype, torch.unique(sample_mask))
# Out:
# [sample 1]
# (1, 128, 128, 128) torch.float32 tensor(0.) tensor(1.)
# (1, 128, 128, 128) torch.float32 tensor([0., 1.])
# [sample 2]
# (1, 128, 128, 128) torch.float32 tensor(0.) tensor(1.)
# (1, 128, 128, 128) torch.float32 tensor([0., 1.])
# [sample 3]
# (1, 128, 128, 128) torch.float32 tensor(0.) tensor(1.)
# (1, 128, 128, 128) torch.float32 tensor([0., 1.])

# %% [markdown]
# 5. 시각화

# %%
ncols, nrows = 10, 6
interval = int(IMAGE_SIZE[-1]//(ncols*nrows/2))
fig, axes = plt.subplots(ncols=ncols, nrows=nrows, figsize=(ncols,nrows))
cnt1, cnt2 = 0, 0
for i in range(nrows):
    for j in range(ncols):
        if i%2 == 0:
            axes[i,j].imshow(SampleSet[0]['image'][0,:,:,cnt1], cmap='gray')
            cnt1+=interval
        else:
            axes[i,j].imshow(SampleSet[0]['label'][0,:,:,cnt2], cmap='gray')
            cnt2+=interval
        axes[i,j].axis('off')
plt.subplots_adjust(wspace=0, hspace=0, left=0, right=1, bottom=0, top=1)
plt.show()

# %% [markdown]
# 6. Data pipeline build

# %%
from monai.data import (
    DataLoader,
    CacheDataset,
    load_decathlon_datalist,
    decollate_batch,
)

train_ds = CacheDataset(
    data=TrainSet,
    transform=transforms,
    cache_num=4,
    cache_rate=1.0,
    num_workers=0)
val_ds = CacheDataset(
    data=ValSet, transform=transforms, cache_num=2, cache_rate=1.0, num_workers=0)
test_ds = CacheDataset(
    data=TestSet, transform=transforms, cache_num=2, cache_rate=1.0, num_workers=0)

train_loader = DataLoader(
    train_ds, batch_size=BATCH_SIZE, shuffle=True, num_workers=0, pin_memory=True)
val_loader = DataLoader(
    val_ds, batch_size=1, shuffle=False, num_workers=0, pin_memory=True)
test_loader = DataLoader(
    test_ds, batch_size=1, shuffle=False, num_workers=0, pin_memory=True)
# Out:
# Loading dataset: 100%|███████████████████████████████████████████████████████| 4/4 [00:02<00:00,  1.76it/s]
# Loading dataset: 100%|███████████████████████████████████████████████████████| 2/2 [00:00<00:00,  2.38it/s]
# Loading dataset: 100%|███████████████████████████████████████████████████████| 2/2 [00:02<00:00,  1.11s/it]

# %% [markdown]
# 7. model build

# %%
import copy
import torch
import torch.nn as nn
import torch.nn.functional as F
import math
from einops import rearrange, reduce, repeat
from einops.layers.torch import Rearrange, Reduce
from torchsummary import summary
from torch import Tensor

class SingleDeconv3DBlock(nn.Module):
    def __init__(self, in_planes, out_planes):
        super().__init__()
        self.block = nn.ConvTranspose3d(in_planes, out_planes, kernel_size=2, stride=2, padding=0, output_padding=0)

    def forward(self, x):
        return self.block(x)


class SingleConv3DBlock(nn.Module):
    def __init__(self, in_planes, out_planes, kernel_size):
        super().__init__()
        self.block = nn.Conv3d(in_planes, out_planes, kernel_size=kernel_size, stride=1,
                               padding=((kernel_size - 1) // 2))

    def forward(self, x):
        return self.block(x)


class Conv3DBlock(nn.Module):
    def __init__(self, in_planes, out_planes, kernel_size=3):
        super().__init__()
        self.block = nn.Sequential(
            SingleConv3DBlock(in_planes, out_planes, kernel_size),
            nn.BatchNorm3d(out_planes),
            nn.ReLU(True)
        )

    def forward(self, x):
        return self.block(x)
    
    
class Deconv3DBlock(nn.Module):
    def __init__(self, in_planes, out_planes, kernel_size=3):
        super().__init__()
        self.block = nn.Sequential(
            SingleDeconv3DBlock(in_planes, out_planes),
            SingleConv3DBlock(out_planes, out_planes, kernel_size),
            nn.BatchNorm3d(out_planes),
            nn.ReLU(True)
        )

    def forward(self, x):
        return self.block(x)    

class Embeddings(nn.Module):
    def __init__(self, input_shape, patch_size=16, embed_dim=768, dropout=0.):
        super().__init__()
        self.patch_size = patch_size
        self.in_channels = input_shape[-4]
        self.n_patches = int((input_shape[-1] * input_shape[-2] * input_shape[-3]) / (patch_size * patch_size * patch_size))
        self.embed_dim = embed_dim
        self.patch_embeddings = nn.Conv3d(in_channels=self.in_channels, out_channels=self.embed_dim,
                                          kernel_size=self.patch_size, stride=self.patch_size)
        self.position_embeddings = nn.Parameter(torch.zeros(1, self.n_patches, self.embed_dim))
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        x = self.patch_embeddings(x)
        x = rearrange(x, "b n h w d -> b (h w d) n")
        # batch, embed_dim, height/patch, width/patch, depth/patch
        embeddings = x + self.position_embeddings
        embeddings = self.dropout(embeddings)
        return embeddings

class MultiHeadAttention(nn.Module):
    def __init__(self, emb_size: int = 768, num_heads: int = 8, dropout: float = 0):
        super().__init__()
        self.emb_size = emb_size
        self.num_heads = num_heads
        # fuse the queries, keys and values in one matrix
        self.qkv = nn.Linear(emb_size, emb_size * 3)
        self.att_drop = nn.Dropout(dropout)
        self.projection = nn.Linear(emb_size, emb_size)
        
    def forward(self, x : Tensor, mask: Tensor = None) -> Tensor:
        # split keys, queries and values in num_heads
        qkv = rearrange(self.qkv(x), "b n (h d qkv) -> (qkv) b h n d", h=self.num_heads, qkv=3)
        queries, keys, values = qkv[0], qkv[1], qkv[2]
        # sum up over the last axis
        energy = torch.einsum('bhqd, bhkd -> bhqk', queries, keys) # batch, num_heads, query_len, key_len
        if mask is not None:
            fill_value = torch.finfo(torch.float32).min
            energy.mask_fill(~mask, fill_value)
            
        scaling = self.emb_size ** (1/2)
        att = F.softmax(energy / scaling, dim=-1)
        att = self.att_drop(att)
        # sum up over the third axis
        out = torch.einsum('bhal, bhlv -> bhav ', att, values)
        out = rearrange(out, "b h n d -> b n (h d)")
        out = self.projection(out)
        return out

class FeedForwardBlock(nn.Sequential):
    def __init__(self, emb_size: int = 768, expansion: int = 4, drop_p: float = 0.):
        super().__init__(
            nn.Linear(emb_size, expansion * emb_size),
            nn.GELU(),
            nn.Dropout(drop_p),
            nn.Linear(expansion * emb_size, emb_size),
        )

class PreNorm(nn.Module):
    def __init__(self, dim, fn):
        super().__init__()
        self.norm = nn.LayerNorm(dim)
        self.fn = fn
    def forward(self, x, **kwargs):
        return self.fn(self.norm(x), **kwargs)
    
class TransformerBlock(nn.Module):
    def __init__(self, embed_dim=768, num_heads=8, depth=12, dropout=0., extract_layers=[3,6,9,12]):
        super().__init__()
        self.layers = nn.ModuleList([])
        for _ in range(depth):
            self.layers.append(nn.ModuleList([
                PreNorm(embed_dim, MultiHeadAttention(embed_dim, num_heads, dropout)),
                PreNorm(embed_dim, FeedForwardBlock(embed_dim, expansion=4))
            ]))            
        self.extract_layers = extract_layers
        
    def forward(self, x):
        extract_layers = []
        
        for cnt, (attn, ff) in enumerate(self.layers):
            x = attn(x) + x
            x = ff(x) + x
            if cnt+1 in self.extract_layers:
                extract_layers.append(x)
            
        return extract_layers

class UNETR(nn.Module):
    def __init__(self, img_shape=(224, 224, 224), input_dim=3, output_dim=3, 
                 embed_dim=768, patch_size=16, num_heads=8, dropout=0.1, light_r=4):
        super().__init__()
        self.input_dim = input_dim
        self.output_dim = output_dim
        self.embed_dim = embed_dim
        self.img_shape = img_shape
        self.patch_size = patch_size
        self.num_heads = num_heads
        self.dropout = dropout
        self.num_layers = 12
        self.ext_layers = [3, 6, 9, 12]

        self.patch_dim = [int(x / patch_size) for x in img_shape]
        self.conv_channels = [int(i/light_r) for i in [32, 64, 128, 256, 512, 1024]]

        self.embedding = Embeddings((input_dim,*img_shape))
        
        # Transformer Encoder
        self.transformer = \
            TransformerBlock(
            )

        # U-Net Decoder
        self.decoder0 = \
            nn.Sequential(
                Conv3DBlock(input_dim, self.conv_channels[0], 3),
                Conv3DBlock(self.conv_channels[0], self.conv_channels[1], 3)
            )

        self.decoder3 = \
            nn.Sequential(
                Deconv3DBlock(embed_dim, self.conv_channels[2]),
                Deconv3DBlock(self.conv_channels[2], self.conv_channels[2]),
                Deconv3DBlock(self.conv_channels[2], self.conv_channels[2])
            )

        self.decoder6 = \
            nn.Sequential(
                Deconv3DBlock(embed_dim, self.conv_channels[3]),
                Deconv3DBlock(self.conv_channels[3], self.conv_channels[3]),
            )

        self.decoder9 = \
            Deconv3DBlock(embed_dim, self.conv_channels[4])

        self.decoder12_upsampler = \
            SingleDeconv3DBlock(embed_dim, self.conv_channels[4])

        self.decoder9_upsampler = \
            nn.Sequential(
                Conv3DBlock(self.conv_channels[5], self.conv_channels[3]),
                Conv3DBlock(self.conv_channels[3], self.conv_channels[3]),
                Conv3DBlock(self.conv_channels[3], self.conv_channels[3]),
                SingleDeconv3DBlock(self.conv_channels[3], self.conv_channels[3])
            )

        self.decoder6_upsampler = \
            nn.Sequential(
                Conv3DBlock(self.conv_channels[4], self.conv_channels[2]),
                Conv3DBlock(self.conv_channels[2], self.conv_channels[2]),
                SingleDeconv3DBlock(self.conv_channels[2], self.conv_channels[2])
            )

        self.decoder3_upsampler = \
            nn.Sequential(
                Conv3DBlock(self.conv_channels[3], self.conv_channels[1]),
                Conv3DBlock(self.conv_channels[1], self.conv_channels[1]),
                SingleDeconv3DBlock(self.conv_channels[1], self.conv_channels[1])
            )

        self.decoder0_header = \
            nn.Sequential(
                Conv3DBlock(self.conv_channels[2], self.conv_channels[1]),
                Conv3DBlock(self.conv_channels[1], self.conv_channels[1]),
                SingleConv3DBlock(self.conv_channels[1], output_dim, 1)
            )

    def forward(self, x):
        z0 = x
        x = self.embedding(x)
        z = self.transformer(x)
        z3, z6, z9, z12 = z
        z3 = z3.transpose(-1, -2).view(-1, self.embed_dim, *self.patch_dim)
        z6 = z6.transpose(-1, -2).view(-1, self.embed_dim, *self.patch_dim)
        z9 = z9.transpose(-1, -2).view(-1, self.embed_dim, *self.patch_dim)
        z12 = z12.transpose(-1, -2).view(-1, self.embed_dim, *self.patch_dim)

        z12 = self.decoder12_upsampler(z12)
        z9 = self.decoder9(z9)
        z9 = self.decoder9_upsampler(torch.cat([z9, z12], dim=1))
        z6 = self.decoder6(z6)
        z6 = self.decoder6_upsampler(torch.cat([z6, z9], dim=1))
        z3 = self.decoder3(z3)
        z3 = self.decoder3_upsampler(torch.cat([z3, z6], dim=1))
        z0 = self.decoder0(z0)
        output = self.decoder0_header(torch.cat([z0, z3], dim=1))
        return output

# %%
model = UNETR(img_shape=IMAGE_SIZE, input_dim=1, output_dim=2, 
              embed_dim=768, patch_size=16, num_heads=8, dropout=0., light_r=4)
model = model.to(DEVICE)
model_summary(model, (1,*IMAGE_SIZE), device=DEVICE.type)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv3d-1         [-1, 768, 8, 8, 8]       3,146,496
#            Dropout-2             [-1, 512, 768]               0
#         Embeddings-3             [-1, 512, 768]               0
#          LayerNorm-4             [-1, 512, 768]           1,536
#             Linear-5            [-1, 512, 2304]       1,771,776
#            Dropout-6          [-1, 8, 512, 512]               0
#             Linear-7             [-1, 512, 768]         590,592
# MultiHeadAttention-8             [-1, 512, 768]               0
#            PreNorm-9             [-1, 512, 768]               0
#         LayerNorm-10             [-1, 512, 768]           1,536
#            Linear-11            [-1, 512, 3072]       2,362,368
#              GELU-12            [-1, 512, 3072]               0
#           Dropout-13            [-1, 512, 3072]               0
#            Linear-14             [-1, 512, 768]       2,360,064
#           PreNorm-15             [-1, 512, 768]               0
#         LayerNorm-16             [-1, 512, 768]           1,536
#            Linear-17            [-1, 512, 2304]       1,771,776
#           Dropout-18          [-1, 8, 512, 512]               0
#            Linear-19             [-1, 512, 768]         590,592
# MultiHeadAttention-20             [-1, 512, 768]               0
#           PreNorm-21             [-1, 512, 768]               0
#         LayerNorm-22             [-1, 512, 768]           1,536
#            Linear-23            [-1, 512, 3072]       2,362,368
#              GELU-24            [-1, 512, 3072]               0
#           Dropout-25            [-1, 512, 3072]               0
#            Linear-26             [-1, 512, 768]       2,360,064
#           PreNorm-27             [-1, 512, 768]               0
#         LayerNorm-28             [-1, 512, 768]           1,536
#            Linear-29            [-1, 512, 2304]       1,771,776
#           Dropout-30          [-1, 8, 512, 512]               0
#            Linear-31             [-1, 512, 768]         590,592
# MultiHeadAttention-32             [-1, 512, 768]               0
#           PreNorm-33             [-1, 512, 768]               0
#         LayerNorm-34             [-1, 512, 768]           1,536
#            Linear-35            [-1, 512, 3072]       2,362,368
#              GELU-36            [-1, 512, 3072]               0
#           Dropout-37            [-1, 512, 3072]               0
#            Linear-38             [-1, 512, 768]       2,360,064
#           PreNorm-39             [-1, 512, 768]               0
#         LayerNorm-40             [-1, 512, 768]           1,536
#            Linear-41            [-1, 512, 2304]       1,771,776
#           Dropout-42          [-1, 8, 512, 512]               0
#            Linear-43             [-1, 512, 768]         590,592
# MultiHeadAttention-44             [-1, 512, 768]               0
#           PreNorm-45             [-1, 512, 768]               0
#         LayerNorm-46             [-1, 512, 768]           1,536
#            Linear-47            [-1, 512, 3072]       2,362,368
#              GELU-48            [-1, 512, 3072]               0
#           Dropout-49            [-1, 512, 3072]               0
#            Linear-50             [-1, 512, 768]       2,360,064
#           PreNorm-51             [-1, 512, 768]               0
#         LayerNorm-52             [-1, 512, 768]           1,536
#            Linear-53            [-1, 512, 2304]       1,771,776
#           Dropout-54          [-1, 8, 512, 512]               0
#            Linear-55             [-1, 512, 768]         590,592
# MultiHeadAttention-56             [-1, 512, 768]               0
#           PreNorm-57             [-1, 512, 768]               0
#         LayerNorm-58             [-1, 512, 768]           1,536
#            Linear-59            [-1, 512, 3072]       2,362,368
#              GELU-60            [-1, 512, 3072]               0
#           Dropout-61            [-1, 512, 3072]               0
#            Linear-62             [-1, 512, 768]       2,360,064
#           PreNorm-63             [-1, 512, 768]               0
#         LayerNorm-64             [-1, 512, 768]           1,536
#            Linear-65            [-1, 512, 2304]       1,771,776
#           Dropout-66          [-1, 8, 512, 512]               0
#            Linear-67             [-1, 512, 768]         590,592
# MultiHeadAttention-68             [-1, 512, 768]               0
#           PreNorm-69             [-1, 512, 768]               0
#         LayerNorm-70             [-1, 512, 768]           1,536
#            Linear-71            [-1, 512, 3072]       2,362,368
#              GELU-72            [-1, 512, 3072]               0
#           Dropout-73            [-1, 512, 3072]               0
#            Linear-74             [-1, 512, 768]       2,360,064
#           PreNorm-75             [-1, 512, 768]               0
#         LayerNorm-76             [-1, 512, 768]           1,536
#            Linear-77            [-1, 512, 2304]       1,771,776
#           Dropout-78          [-1, 8, 512, 512]               0
#            Linear-79             [-1, 512, 768]         590,592
# MultiHeadAttention-80             [-1, 512, 768]               0
#           PreNorm-81             [-1, 512, 768]               0
#         LayerNorm-82             [-1, 512, 768]           1,536
#            Linear-83            [-1, 512, 3072]       2,362,368
#              GELU-84            [-1, 512, 3072]               0
#           Dropout-85            [-1, 512, 3072]               0
#            Linear-86             [-1, 512, 768]       2,360,064
#           PreNorm-87             [-1, 512, 768]               0
#         LayerNorm-88             [-1, 512, 768]           1,536
#            Linear-89            [-1, 512, 2304]       1,771,776
#           Dropout-90          [-1, 8, 512, 512]               0
#            Linear-91             [-1, 512, 768]         590,592
# MultiHeadAttention-92             [-1, 512, 768]               0
#           PreNorm-93             [-1, 512, 768]               0
#         LayerNorm-94             [-1, 512, 768]           1,536
#            Linear-95            [-1, 512, 3072]       2,362,368
#              GELU-96            [-1, 512, 3072]               0
#           Dropout-97            [-1, 512, 3072]               0
#            Linear-98             [-1, 512, 768]       2,360,064
#           PreNorm-99             [-1, 512, 768]               0
#        LayerNorm-100             [-1, 512, 768]           1,536
#           Linear-101            [-1, 512, 2304]       1,771,776
#          Dropout-102          [-1, 8, 512, 512]               0
#           Linear-103             [-1, 512, 768]         590,592
# MultiHeadAttention-104             [-1, 512, 768]               0
#          PreNorm-105             [-1, 512, 768]               0
#        LayerNorm-106             [-1, 512, 768]           1,536
#           Linear-107            [-1, 512, 3072]       2,362,368
#             GELU-108            [-1, 512, 3072]               0
#          Dropout-109            [-1, 512, 3072]               0
#           Linear-110             [-1, 512, 768]       2,360,064
#          PreNorm-111             [-1, 512, 768]               0
#        LayerNorm-112             [-1, 512, 768]           1,536
#           Linear-113            [-1, 512, 2304]       1,771,776
#          Dropout-114          [-1, 8, 512, 512]               0
#           Linear-115             [-1, 512, 768]         590,592
# MultiHeadAttention-116             [-1, 512, 768]               0
#          PreNorm-117             [-1, 512, 768]               0
#        LayerNorm-118             [-1, 512, 768]           1,536
#           Linear-119            [-1, 512, 3072]       2,362,368
#             GELU-120            [-1, 512, 3072]               0
#          Dropout-121            [-1, 512, 3072]               0
#           Linear-122             [-1, 512, 768]       2,360,064
#          PreNorm-123             [-1, 512, 768]               0
#        LayerNorm-124             [-1, 512, 768]           1,536
#           Linear-125            [-1, 512, 2304]       1,771,776
#          Dropout-126          [-1, 8, 512, 512]               0
#           Linear-127             [-1, 512, 768]         590,592
# MultiHeadAttention-128             [-1, 512, 768]               0
#          PreNorm-129             [-1, 512, 768]               0
#        LayerNorm-130             [-1, 512, 768]           1,536
#           Linear-131            [-1, 512, 3072]       2,362,368
#             GELU-132            [-1, 512, 3072]               0
#          Dropout-133            [-1, 512, 3072]               0
#           Linear-134             [-1, 512, 768]       2,360,064
#          PreNorm-135             [-1, 512, 768]               0
#        LayerNorm-136             [-1, 512, 768]           1,536
#           Linear-137            [-1, 512, 2304]       1,771,776
#          Dropout-138          [-1, 8, 512, 512]               0
#           Linear-139             [-1, 512, 768]         590,592
# MultiHeadAttention-140             [-1, 512, 768]               0
#          PreNorm-141             [-1, 512, 768]               0
#        LayerNorm-142             [-1, 512, 768]           1,536
#           Linear-143            [-1, 512, 3072]       2,362,368
#             GELU-144            [-1, 512, 3072]               0
#          Dropout-145            [-1, 512, 3072]               0
#           Linear-146             [-1, 512, 768]       2,360,064
#          PreNorm-147             [-1, 512, 768]               0
# TransformerBlock-148  [[-1, 512, 768], [-1, 512, 768], [-1, 512, 768], [-1, 512, 768]]               0
#  ConvTranspose3d-149      [-1, 128, 16, 16, 16]         786,560
# SingleDeconv3DBlock-150      [-1, 128, 16, 16, 16]               0
#  ConvTranspose3d-151      [-1, 128, 16, 16, 16]         786,560
# SingleDeconv3DBlock-152      [-1, 128, 16, 16, 16]               0
#           Conv3d-153      [-1, 128, 16, 16, 16]         442,496
# SingleConv3DBlock-154      [-1, 128, 16, 16, 16]               0
#      BatchNorm3d-155      [-1, 128, 16, 16, 16]             256
#             ReLU-156      [-1, 128, 16, 16, 16]               0
#    Deconv3DBlock-157      [-1, 128, 16, 16, 16]               0
#           Conv3d-158       [-1, 64, 16, 16, 16]         442,432
# SingleConv3DBlock-159       [-1, 64, 16, 16, 16]               0
#      BatchNorm3d-160       [-1, 64, 16, 16, 16]             128
#             ReLU-161       [-1, 64, 16, 16, 16]               0
#      Conv3DBlock-162       [-1, 64, 16, 16, 16]               0
#           Conv3d-163       [-1, 64, 16, 16, 16]         110,656
# SingleConv3DBlock-164       [-1, 64, 16, 16, 16]               0
#      BatchNorm3d-165       [-1, 64, 16, 16, 16]             128
#             ReLU-166       [-1, 64, 16, 16, 16]               0
#      Conv3DBlock-167       [-1, 64, 16, 16, 16]               0
#           Conv3d-168       [-1, 64, 16, 16, 16]         110,656
# SingleConv3DBlock-169       [-1, 64, 16, 16, 16]               0
#      BatchNorm3d-170       [-1, 64, 16, 16, 16]             128
#             ReLU-171       [-1, 64, 16, 16, 16]               0
#      Conv3DBlock-172       [-1, 64, 16, 16, 16]               0
#  ConvTranspose3d-173       [-1, 64, 32, 32, 32]          32,832
# SingleDeconv3DBlock-174       [-1, 64, 32, 32, 32]               0
#  ConvTranspose3d-175       [-1, 64, 16, 16, 16]         393,280
# SingleDeconv3DBlock-176       [-1, 64, 16, 16, 16]               0
#           Conv3d-177       [-1, 64, 16, 16, 16]         110,656
# SingleConv3DBlock-178       [-1, 64, 16, 16, 16]               0
#      BatchNorm3d-179       [-1, 64, 16, 16, 16]             128
#             ReLU-180       [-1, 64, 16, 16, 16]               0
#    Deconv3DBlock-181       [-1, 64, 16, 16, 16]               0
#  ConvTranspose3d-182       [-1, 64, 32, 32, 32]          32,832
# SingleDeconv3DBlock-183       [-1, 64, 32, 32, 32]               0
#           Conv3d-184       [-1, 64, 32, 32, 32]         110,656
# SingleConv3DBlock-185       [-1, 64, 32, 32, 32]               0
#      BatchNorm3d-186       [-1, 64, 32, 32, 32]             128
#             ReLU-187       [-1, 64, 32, 32, 32]               0
#    Deconv3DBlock-188       [-1, 64, 32, 32, 32]               0
#           Conv3d-189       [-1, 32, 32, 32, 32]         110,624
# SingleConv3DBlock-190       [-1, 32, 32, 32, 32]               0
#      BatchNorm3d-191       [-1, 32, 32, 32, 32]              64
#             ReLU-192       [-1, 32, 32, 32, 32]               0
#      Conv3DBlock-193       [-1, 32, 32, 32, 32]               0
#           Conv3d-194       [-1, 32, 32, 32, 32]          27,680
# SingleConv3DBlock-195       [-1, 32, 32, 32, 32]               0
#      BatchNorm3d-196       [-1, 32, 32, 32, 32]              64
#             ReLU-197       [-1, 32, 32, 32, 32]               0
#      Conv3DBlock-198       [-1, 32, 32, 32, 32]               0
#  ConvTranspose3d-199       [-1, 32, 64, 64, 64]           8,224
# SingleDeconv3DBlock-200       [-1, 32, 64, 64, 64]               0
#  ConvTranspose3d-201       [-1, 32, 16, 16, 16]         196,640
# SingleDeconv3DBlock-202       [-1, 32, 16, 16, 16]               0
#           Conv3d-203       [-1, 32, 16, 16, 16]          27,680
# SingleConv3DBlock-204       [-1, 32, 16, 16, 16]               0
#      BatchNorm3d-205       [-1, 32, 16, 16, 16]              64
#             ReLU-206       [-1, 32, 16, 16, 16]               0
#    Deconv3DBlock-207       [-1, 32, 16, 16, 16]               0
#  ConvTranspose3d-208       [-1, 32, 32, 32, 32]           8,224
# SingleDeconv3DBlock-209       [-1, 32, 32, 32, 32]               0
#           Conv3d-210       [-1, 32, 32, 32, 32]          27,680
# SingleConv3DBlock-211       [-1, 32, 32, 32, 32]               0
#      BatchNorm3d-212       [-1, 32, 32, 32, 32]              64
#             ReLU-213       [-1, 32, 32, 32, 32]               0
#    Deconv3DBlock-214       [-1, 32, 32, 32, 32]               0
#  ConvTranspose3d-215       [-1, 32, 64, 64, 64]           8,224
# SingleDeconv3DBlock-216       [-1, 32, 64, 64, 64]               0
#           Conv3d-217       [-1, 32, 64, 64, 64]          27,680
# SingleConv3DBlock-218       [-1, 32, 64, 64, 64]               0
#      BatchNorm3d-219       [-1, 32, 64, 64, 64]              64
#             ReLU-220       [-1, 32, 64, 64, 64]               0
#    Deconv3DBlock-221       [-1, 32, 64, 64, 64]               0
#           Conv3d-222       [-1, 16, 64, 64, 64]          27,664
# SingleConv3DBlock-223       [-1, 16, 64, 64, 64]               0
#      BatchNorm3d-224       [-1, 16, 64, 64, 64]              32
#             ReLU-225       [-1, 16, 64, 64, 64]               0
#      Conv3DBlock-226       [-1, 16, 64, 64, 64]               0
#           Conv3d-227       [-1, 16, 64, 64, 64]           6,928
# SingleConv3DBlock-228       [-1, 16, 64, 64, 64]               0
#      BatchNorm3d-229       [-1, 16, 64, 64, 64]              32
#             ReLU-230       [-1, 16, 64, 64, 64]               0
#      Conv3DBlock-231       [-1, 16, 64, 64, 64]               0
#  ConvTranspose3d-232    [-1, 16, 128, 128, 128]           2,064
# SingleDeconv3DBlock-233    [-1, 16, 128, 128, 128]               0
#           Conv3d-234     [-1, 8, 128, 128, 128]             224
# SingleConv3DBlock-235     [-1, 8, 128, 128, 128]               0
#      BatchNorm3d-236     [-1, 8, 128, 128, 128]              16
#             ReLU-237     [-1, 8, 128, 128, 128]               0
#      Conv3DBlock-238     [-1, 8, 128, 128, 128]               0
#           Conv3d-239    [-1, 16, 128, 128, 128]           3,472
# SingleConv3DBlock-240    [-1, 16, 128, 128, 128]               0
#      BatchNorm3d-241    [-1, 16, 128, 128, 128]              32
#             ReLU-242    [-1, 16, 128, 128, 128]               0
#      Conv3DBlock-243    [-1, 16, 128, 128, 128]               0
#           Conv3d-244    [-1, 16, 128, 128, 128]          13,840
# SingleConv3DBlock-245    [-1, 16, 128, 128, 128]               0
#      BatchNorm3d-246    [-1, 16, 128, 128, 128]              32
#             ReLU-247    [-1, 16, 128, 128, 128]               0
#      Conv3DBlock-248    [-1, 16, 128, 128, 128]               0
#           Conv3d-249    [-1, 16, 128, 128, 128]           6,928
# SingleConv3DBlock-250    [-1, 16, 128, 128, 128]               0
#      BatchNorm3d-251    [-1, 16, 128, 128, 128]              32
#             ReLU-252    [-1, 16, 128, 128, 128]               0
#      Conv3DBlock-253    [-1, 16, 128, 128, 128]               0
#           Conv3d-254     [-1, 2, 128, 128, 128]              34
# SingleConv3DBlock-255     [-1, 2, 128, 128, 128]               0
# ================================================================
# Total params: 92,065,778
# Trainable params: 92,065,778
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 8.00
# Forward/backward pass size (MB): 7312.00
# Params size (MB): 351.20
# Estimated Total Size (MB): 7671.20
# ----------------------------------------------------------------

# %% [markdown]
# 8. optimizer, loss, metric 등 구성

# %%
from monai.losses import DiceCELoss, DiceLoss

torch.backends.cudnn.benchmark = True # ??

optimizer = torch.optim.Adam(model.parameters(), lr=1e-4, weight_decay=1e-4)
# scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=50, gamma=0.1)

LossFuncion = monai.losses.DiceLoss(include_background=False, to_onehot_y=False, softmax=True)
MetricDice = monai.metrics.DiceMetric(include_background=False, reduction="mean")

# %%
def BinaryOutput(output, keepdim=True):
    shape = output.shape
    argmax_idx = torch.argmax(output, axis=1, keepdim=True)
    argmax_oh = F.one_hot(argmax_idx, num_classes=NUM_CLASS)
    if keepdim:
        argmax_oh = torch.squeeze(argmax_oh, dim=1)
    if len(shape) == 5:
        argmax_oh = argmax_oh.permute(0,4,1,2,3)
    elif len(shape) == 4:
        argmax_oh = argmax_oh.permute(0,3,1,2)
    
    return argmax_oh

# %% [markdown]
# 9. train & evalute loop

# %%
from monai.losses.dice import DiceLoss, one_hot

def train(epoch, train_loader):
    model.train()
    mean_epoch_loss = 0
    mean_dice_score = 0
    epoch_iterator = tqdm(
        train_loader, desc="Training (X / X EPOCHS) (loss=X.X) (dice score=%.5f)", 
        dynamic_ncols=True)
    
    for step, batch in enumerate(epoch_iterator):
        x, y = (batch["image"].cuda(), batch["label"].cuda())
        y = torch.squeeze(y, dim=1)
        y = one_hot(y[:, None, ...], num_classes=NUM_CLASS)
        
        logit_map = model(x)
        loss = LossFuncion(logit_map, y)
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()
        mean_epoch_loss += loss.item()
        
        bi_output = BinaryOutput(logit_map)
        MetricDice(bi_output, y)
        dice_score = MetricDice.aggregate().item()
        mean_dice_score += dice_score
        
        epoch_iterator.set_description(
            "Training (%d / %d EPOCHS) (loss=%2.5f) (dice score=%.5f)" 
            % (epoch, EPOCHS, loss, dice_score))
    
    mean_epoch_loss /= len(epoch_iterator)
    mean_dice_score /= len(epoch_iterator)
    
    return mean_epoch_loss, mean_dice_score



def evaluate(epoch, test_loader):
    model.eval() 
    mean_epoch_loss = 0
    mean_dice_score = 0
    epoch_iterator = tqdm(
        test_loader, desc="Evaluating (X / X EPOCHS) (loss=X.X) (dice score=%.5f)", 
        dynamic_ncols=True)
    
    with torch.no_grad():
        for step, batch in enumerate(epoch_iterator):
            x, y = (batch["image"].cuda(), batch["label"].cuda())
            y = torch.squeeze(y, dim=1)
            y = one_hot(y[:, None, ...], num_classes=NUM_CLASS)

            logit_map = model(x)
            loss = LossFuncion(logit_map, y)
            mean_epoch_loss += loss.item()

            bi_output = BinaryOutput(logit_map)
            MetricDice(bi_output, y)
            dice_score = MetricDice.aggregate().item()
            mean_dice_score += dice_score

            epoch_iterator.set_description(
                "Evaluating (%d / %d EPOCHS) (loss=%2.5f) (dice score=%.5f)" 
                % (epoch, EPOCHS, loss, dice_score))

    mean_epoch_loss /= len(epoch_iterator)
    mean_dice_score /= len(epoch_iterator)
    
    MetricDice.reset() # reset the status for next validation round
    
    return mean_epoch_loss, mean_dice_score

# %% [markdown]
# 10. let's training

# %%
losses = {'train':[], 'val':[]}
dice_scores = {'train':[], 'val':[]}
best_metric, best_epoch = 999, -1

for epoch in range(1, EPOCHS+1):
    train_loss, train_dice_score = train(epoch, train_loader)
    val_loss, val_dice_score = evaluate(epoch, val_loader)
    
    losses['train'].append(train_loss)
    losses['val'].append(val_loss)
    dice_scores['train'].append(train_dice_score)
    dice_scores['val'].append(val_dice_score)

    if losses['val'][-1] < best_metric:
        best_metric = losses['val'][-1]
        best_epoch = epoch
        print(f'Best record! [{epoch}] Test Loss: {val_loss:.6f}, Dice score: {val_dice_score:.6f}')
        if MODEL_SAVE:
            model_name = f'./{best_epoch}_{best_metric}.pth'
            torch.save(model.state_dict(), os.path.join(MODEL_SAVE_PATH, model_name))
            print('saved model')
# Out:
# Training (1 / 200 EPOCHS) (loss=0.98787) (dice score=0.01736): 100%|███████| 14/14 [00:28<00:00,  2.03s/it]
# Evaluating (1 / 200 EPOCHS) (loss=0.99119) (dice score=0.01703): 100%|███████| 8/8 [00:04<00:00,  1.83it/s]
# Best record! [1] Test Loss: 0.988644, Dice score: 0.017011
# saved model
# Training (2 / 200 EPOCHS) (loss=0.97278) (dice score=0.02120): 100%|███████| 14/14 [00:23<00:00,  1.69s/it]
# Evaluating (2 / 200 EPOCHS) (loss=0.98974) (dice score=0.02179): 100%|███████| 8/8 [00:03<00:00,  2.20it/s]
# Best record! [2] Test Loss: 0.986852, Dice score: 0.021221
# saved model
# Training (3 / 200 EPOCHS) (loss=0.99113) (dice score=0.02278): 100%|███████| 14/14 [00:23<00:00,  1.67s/it]
# Evaluating (3 / 200 EPOCHS) (loss=0.98756) (dice score=0.02300): 100%|███████| 8/8 [00:03<00:00,  2.22it/s]
# Best record! [3] Test Loss: 0.984314, Dice score: 0.022625
# saved model
# Training (4 / 200 EPOCHS) (loss=0.98381) (dice score=0.02305): 100%|███████| 14/14 [00:23<00:00,  1.67s/it]
# Evaluating (4 / 200 EPOCHS) (loss=0.98085) (dice score=0.02465): 100%|███████| 8/8 [00:03<00:00,  2.23it/s]
# Best record! [4] Test Loss: 0.978210, Dice score: 0.023735
# saved model
# Training (5 / 200 EPOCHS) (loss=0.98270) (dice score=0.02675): 100%|███████| 14/14 [00:23<00:00,  1.68s/it]
# Evaluating (5 / 200 EPOCHS) (loss=0.98158) (dice score=0.04259): 100%|███████| 8/8 [00:03<00:00,  2.22it/s]
# Best record! [5] Test Loss: 0.977532, Dice score: 0.035751
# saved model
# Training (6 / 200 EPOCHS) (loss=0.97509) (dice score=0.03763): 100%|███████| 14/14 [00:23<00:00,  1.67s/it]
# Evaluating (6 / 200 EPOCHS) (loss=0.97879) (dice score=0.03646): 100%|███████| 8/8 [00:03<00:00,  2.21it/s]
# Best record! [6] Test Loss: 0.976044, Dice score: 0.036467
# saved model
# Training (7 / 200 EPOCHS) (loss=0.97387) (dice score=0.05094): 100%|███████| 14/14 [00:23<00:00,  1.67s/it]
# Evaluating (7 / 200 EPOCHS) (loss=0.97813) (dice score=0.05682): 100%|███████| 8/8 [00:03<00:00,  2.23it/s]
# Best record! [7] Test Loss: 0.973195, Dice score: 0.053981
# saved model
# Training (8 / 200 EPOCHS) (loss=0.97652) (dice score=0.07372): 100%|███████| 14/14 [00:23<00:00,  1.67s/it]
# Evaluating (8 / 200 EPOCHS) (loss=0.97721) (dice score=0.07363): 100%|███████| 8/8 [00:03<00:00,  2.21it/s]
# Best record! [8] Test Loss: 0.973015, Dice score: 0.073244
# saved model
# Training (9 / 200 EPOCHS) (loss=0.97809) (dice score=0.08654): 100%|███████| 14/14 [00:23<00:00,  1.68s/it]
# Evaluating (9 / 200 EPOCHS) (loss=0.97680) (dice score=0.09632): 100%|███████| 8/8 [00:03<00:00,  2.23it/s]
# Best record! [9] Test Loss: 0.972387, Dice score: 0.091567
# saved model
# Training (10 / 200 EPOCHS) (loss=0.98148) (dice score=0.14173): 100%|██████| 14/14 [00:23<00:00,  1.67s/it]
# Evaluating (10 / 200 EPOCHS) (loss=0.97586) (dice score=0.14184): 100%|██████| 8/8 [00:03<00:00,  2.24it/s]
# Training (11 / 200 EPOCHS) (loss=0.98781) (dice score=0.14535): 100%|██████| 14/14 [00:23<00:00,  1.68s/it]
# Evaluating (11 / 200 EPOCHS) (loss=0.97540) (dice score=0.18143): 100%|██████| 8/8 [00:03<00:00,  2.22it/s]
# Training (12 / 200 EPOCHS) (loss=0.98322) (dice score=0.17974): 100%|██████| 14/14 [00:23<00:00,  1.68s/it]
# Evaluating (12 / 200 EPOCHS) (loss=0.97654) (dice score=0.16451): 100%|██████| 8/8 [00:03<00:00,  2.23it/s]
# Training (13 / 200 EPOCHS) (loss=0.97521) (dice score=0.16671): 100%|██████| 14/14 [00:23<00:00,  1.67s/it]
# Evaluating (13 / 200 EPOCHS) (loss=0.97955) (dice score=0.15941): 100%|██████| 8/8 [00:03<00:00,  2.22it/s]
# Training (14 / 200 EPOCHS) (loss=0.98291) (dice score=0.16939): 100%|██████| 14/14 [00:23<00:00,  1.68s/it]
# Evaluating (14 / 200 EPOCHS) (loss=0.97460) (dice score=0.18821): 100%|██████| 8/8 [00:03<00:00,  2.22it/s]
# Best record! [14] Test Loss: 0.971301, Dice score: 0.181594
# saved model
# Training (15 / 200 EPOCHS) (loss=0.97424) (dice score=0.17992): 100%|██████| 14/14 [00:23<00:00,  1.68s/it]
# Evaluating (15 / 200 EPOCHS) (loss=0.97483) (dice score=0.17636): 100%|██████| 8/8 [00:03<00:00,  2.25it/s]
# Best record! [15] Test Loss: 0.970207, Dice score: 0.177037
# saved model
# Training (16 / 200 EPOCHS) (loss=0.97219) (dice score=0.19664): 100%|██████| 14/14 [00:23<00:00,  1.67s/it]
# Evaluating (16 / 200 EPOCHS) (loss=0.97378) (dice score=0.22572): 100%|██████| 8/8 [00:03<00:00,  2.23it/s]
# Training (17 / 200 EPOCHS) (loss=0.98326) (dice score=0.20032): 100%|██████| 14/14 [00:23<00:00,  1.67s/it]
# Evaluating (17 / 200 EPOCHS) (loss=0.97323) (dice score=0.21371): 100%|██████| 8/8 [00:03<00:00,  2.24it/s]
# Training (18 / 200 EPOCHS) (loss=0.97426) (dice score=0.20810): 100%|██████| 14/14 [00:23<00:00,  1.67s/it]
# Evaluating (18 / 200 EPOCHS) (loss=0.97344) (dice score=0.21624): 100%|██████| 8/8 [00:03<00:00,  2.22it/s]
# Training (19 / 200 EPOCHS) (loss=0.96794) (dice score=0.24163): 100%|██████| 14/14 [00:23<00:00,  1.67s/it]
# Evaluating (19 / 200 EPOCHS) (loss=0.97445) (dice score=0.21524): 100%|██████| 8/8 [00:03<00:00,  2.23it/s]
# Best record! [19] Test Loss: 0.968957, Dice score: 0.224575
# saved model
# Training (20 / 200 EPOCHS) (loss=0.95161) (dice score=0.25043): 100%|██████| 14/14 [00:23<00:00,  1.67s/it]
# Evaluating (20 / 200 EPOCHS) (loss=0.97258) (dice score=0.24950): 100%|██████| 8/8 [00:03<00:00,  2.23it/s]
# Best record! [20] Test Loss: 0.967935, Dice score: 0.249310
# saved model
# Training (21 / 200 EPOCHS) (loss=0.96672) (dice score=0.22524): 100%|██████| 14/14 [00:23<00:00,  1.67s/it]
# Evaluating (21 / 200 EPOCHS) (loss=0.97241) (dice score=0.22472): 100%|██████| 8/8 [00:03<00:00,  2.23it/s]
# Best record! [21] Test Loss: 0.967908, Dice score: 0.224763
# saved model
# Training (22 / 200 EPOCHS) (loss=0.98488) (dice score=0.24410): 100%|██████| 14/14 [00:23<00:00,  1.67s/it]
# Evaluating (22 / 200 EPOCHS) (loss=0.97516) (dice score=0.28284): 100%|██████| 8/8 [00:03<00:00,  2.23it/s]
# Training (23 / 200 EPOCHS) (loss=0.98181) (dice score=0.24641): 100%|██████| 14/14 [00:23<00:00,  1.67s/it]
# Evaluating (23 / 200 EPOCHS) (loss=0.97203) (dice score=0.28613): 100%|██████| 8/8 [00:03<00:00,  2.24it/s]
# Training (24 / 200 EPOCHS) (loss=0.96369) (dice score=0.25234): 100%|██████| 14/14 [00:23<00:00,  1.67s/it]
# Evaluating (24 / 200 EPOCHS) (loss=0.97097) (dice score=0.27482): 100%|██████| 8/8 [00:03<00:00,  2.23it/s]
# Training (25 / 200 EPOCHS) (loss=0.94669) (dice score=0.26527): 100%|██████| 14/14 [00:23<00:00,  1.69s/it]
# Evaluating (25 / 200 EPOCHS) (loss=0.97064) (dice score=0.26900): 100%|██████| 8/8 [00:03<00:00,  2.21it/s]
# Best record! [25] Test Loss: 0.966975, Dice score: 0.266683
# saved model
# Training (26 / 200 EPOCHS) (loss=0.97857) (dice score=0.26080): 100%|██████| 14/14 [00:23<00:00,  1.67s/it]
# Evaluating (26 / 200 EPOCHS) (loss=0.96976) (dice score=0.28611): 100%|██████| 8/8 [00:03<00:00,  2.22it/s]
# Training (27 / 200 EPOCHS) (loss=0.96872) (dice score=0.34776): 100%|██████| 14/14 [00:23<00:00,  1.66s/it]
# Evaluating (27 / 200 EPOCHS) (loss=0.97081) (dice score=0.31646): 100%|██████| 8/8 [00:03<00:00,  2.23it/s]
# Training (28 / 200 EPOCHS) (loss=0.94906) (dice score=0.30023): 100%|██████| 14/14 [00:23<00:00,  1.67s/it]
# Evaluating (28 / 200 EPOCHS) (loss=0.96930) (dice score=0.30034): 100%|██████| 8/8 [00:03<00:00,  2.21it/s]
# Best record! [28] Test Loss: 0.964121, Dice score: 0.297635
# saved model
# Training (29 / 200 EPOCHS) (loss=0.95229) (dice score=0.30938): 100%|██████| 14/14 [00:23<00:00,  1.66s/it]
# Evaluating (29 / 200 EPOCHS) (loss=0.96893) (dice score=0.30840): 100%|██████| 8/8 [00:03<00:00,  2.24it/s]
# Training (30 / 200 EPOCHS) (loss=0.98292) (dice score=0.33363): 100%|██████| 14/14 [00:23<00:00,  1.66s/it]
# Evaluating (30 / 200 EPOCHS) (loss=0.96800) (dice score=0.34625): 100%|██████| 8/8 [00:03<00:00,  2.24it/s]
# Training (31 / 200 EPOCHS) (loss=0.97699) (dice score=0.32123): 100%|██████| 14/14 [00:23<00:00,  1.67s/it]
# Evaluating (31 / 200 EPOCHS) (loss=0.96949) (dice score=0.36436): 100%|██████| 8/8 [00:03<00:00,  2.25it/s]
# Training (32 / 200 EPOCHS) (loss=0.97802) (dice score=0.33015): 100%|██████| 14/14 [00:23<00:00,  1.66s/it]
# Evaluating (32 / 200 EPOCHS) (loss=0.96716) (dice score=0.29599): 100%|██████| 8/8 [00:03<00:00,  2.22it/s]
# Best record! [32] Test Loss: 0.962908, Dice score: 0.306254
# saved model
# Training (33 / 200 EPOCHS) (loss=0.95585) (dice score=0.29735): 100%|██████| 14/14 [00:23<00:00,  1.67s/it]
# Evaluating (33 / 200 EPOCHS) (loss=0.96845) (dice score=0.28796): 100%|██████| 8/8 [00:03<00:00,  2.23it/s]
# Best record! [33] Test Loss: 0.962824, Dice score: 0.292919
# saved model
# Training (34 / 200 EPOCHS) (loss=0.97072) (dice score=0.34494): 100%|██████| 14/14 [00:23<00:00,  1.67s/it]
# Evaluating (34 / 200 EPOCHS) (loss=0.96716) (dice score=0.35489): 100%|██████| 8/8 [00:03<00:00,  2.24it/s]
# Training (35 / 200 EPOCHS) (loss=0.96785) (dice score=0.35129): 100%|██████| 14/14 [00:23<00:00,  1.68s/it]
# Evaluating (35 / 200 EPOCHS) (loss=0.96683) (dice score=0.35512): 100%|██████| 8/8 [00:03<00:00,  2.24it/s]
# Best record! [35] Test Loss: 0.962629, Dice score: 0.354120
# saved model
# Training (36 / 200 EPOCHS) (loss=0.96362) (dice score=0.34636): 100%|██████| 14/14 [00:23<00:00,  1.68s/it]
# Evaluating (36 / 200 EPOCHS) (loss=0.96977) (dice score=0.33740): 100%|██████| 8/8 [00:03<00:00,  2.23it/s]
# Training (37 / 200 EPOCHS) (loss=0.96657) (dice score=0.36088): 100%|██████| 14/14 [00:23<00:00,  1.67s/it]
# Evaluating (37 / 200 EPOCHS) (loss=0.96546) (dice score=0.35564): 100%|██████| 8/8 [00:03<00:00,  2.23it/s]
# Best record! [37] Test Loss: 0.960068, Dice score: 0.357601
# saved model
# Training (38 / 200 EPOCHS) (loss=0.95705) (dice score=0.33458): 100%|██████| 14/14 [00:23<00:00,  1.68s/it]
# Evaluating (38 / 200 EPOCHS) (loss=0.96577) (dice score=0.32130): 100%|██████| 8/8 [00:03<00:00,  2.23it/s]
# Training (39 / 200 EPOCHS) (loss=0.95554) (dice score=0.35309): 100%|██████| 14/14 [00:23<00:00,  1.68s/it]
# Evaluating (39 / 200 EPOCHS) (loss=0.96364) (dice score=0.34936): 100%|██████| 8/8 [00:03<00:00,  2.21it/s]
# Best record! [39] Test Loss: 0.958996, Dice score: 0.349914
# saved model
# Training (40 / 200 EPOCHS) (loss=0.96530) (dice score=0.32992): 100%|██████| 14/14 [00:23<00:00,  1.67s/it]
# Evaluating (40 / 200 EPOCHS) (loss=0.96404) (dice score=0.34212): 100%|██████| 8/8 [00:03<00:00,  2.23it/s]
# Training (41 / 200 EPOCHS) (loss=0.95201) (dice score=0.32161): 100%|██████| 14/14 [00:23<00:00,  1.67s/it]
# Evaluating (41 / 200 EPOCHS) (loss=0.96320) (dice score=0.31428): 100%|██████| 8/8 [00:03<00:00,  2.21it/s]
# Best record! [41] Test Loss: 0.956606, Dice score: 0.316809
# saved model
# Training (42 / 200 EPOCHS) (loss=0.93834) (dice score=0.36585): 100%|██████| 14/14 [00:23<00:00,  1.67s/it]
# Evaluating (42 / 200 EPOCHS) (loss=0.96246) (dice score=0.34659): 100%|██████| 8/8 [00:03<00:00,  2.22it/s]
# Training (43 / 200 EPOCHS) (loss=0.97318) (dice score=0.35525): 100%|██████| 14/14 [00:23<00:00,  1.68s/it]
# Evaluating (43 / 200 EPOCHS) (loss=0.96201) (dice score=0.37108): 100%|██████| 8/8 [00:03<00:00,  2.23it/s]
# Training (44 / 200 EPOCHS) (loss=0.92789) (dice score=0.40541): 100%|██████| 14/14 [00:23<00:00,  1.68s/it]
# Evaluating (44 / 200 EPOCHS) (loss=0.96228) (dice score=0.42788): 100%|██████| 8/8 [00:03<00:00,  2.22it/s]
# Training (45 / 200 EPOCHS) (loss=0.96216) (dice score=0.36800): 100%|██████| 14/14 [00:23<00:00,  1.67s/it]
# Evaluating (45 / 200 EPOCHS) (loss=0.96839) (dice score=0.31577): 100%|██████| 8/8 [00:03<00:00,  2.22it/s]
# Training (46 / 200 EPOCHS) (loss=0.97512) (dice score=0.37553): 100%|██████| 14/14 [00:23<00:00,  1.67s/it]
# Evaluating (46 / 200 EPOCHS) (loss=0.96907) (dice score=0.37222): 100%|██████| 8/8 [00:03<00:00,  2.23it/s]
# Training (47 / 200 EPOCHS) (loss=0.96528) (dice score=0.38877): 100%|██████| 14/14 [00:23<00:00,  1.68s/it]
# Evaluating (47 / 200 EPOCHS) (loss=0.96008) (dice score=0.40483): 100%|██████| 8/8 [00:03<00:00,  2.21it/s]
# Training (48 / 200 EPOCHS) (loss=0.95374) (dice score=0.39905): 100%|██████| 14/14 [00:23<00:00,  1.67s/it]
# Evaluating (48 / 200 EPOCHS) (loss=0.96636) (dice score=0.34278): 100%|██████| 8/8 [00:03<00:00,  2.23it/s]
# Training (49 / 200 EPOCHS) (loss=0.94006) (dice score=0.32662): 100%|██████| 14/14 [00:23<00:00,  1.67s/it]
# Evaluating (49 / 200 EPOCHS) (loss=0.96233) (dice score=0.29105): 100%|██████| 8/8 [00:03<00:00,  2.23it/s]
# Best record! [49] Test Loss: 0.955097, Dice score: 0.303163
# saved model
# Training (50 / 200 EPOCHS) (loss=0.96915) (dice score=0.33405): 100%|██████| 14/14 [00:23<00:00,  1.67s/it]
# Evaluating (50 / 200 EPOCHS) (loss=0.96375) (dice score=0.36020): 100%|██████| 8/8 [00:03<00:00,  2.19it/s]
# Training (51 / 200 EPOCHS) (loss=0.97033) (dice score=0.35985): 100%|██████| 14/14 [00:23<00:00,  1.68s/it]
# Evaluating (51 / 200 EPOCHS) (loss=0.95796) (dice score=0.36723): 100%|██████| 8/8 [00:03<00:00,  2.22it/s]
# Training (52 / 200 EPOCHS) (loss=0.97814) (dice score=0.38533): 100%|██████| 14/14 [00:23<00:00,  1.68s/it]
# Evaluating (52 / 200 EPOCHS) (loss=0.95620) (dice score=0.38859): 100%|██████| 8/8 [00:03<00:00,  2.20it/s]
# Training (53 / 200 EPOCHS) (loss=0.97588) (dice score=0.42429): 100%|██████| 14/14 [00:23<00:00,  1.68s/it]
# Evaluating (53 / 200 EPOCHS) (loss=0.95503) (dice score=0.43020): 100%|██████| 8/8 [00:03<00:00,  2.23it/s]
# Training (54 / 200 EPOCHS) (loss=0.96443) (dice score=0.45700): 100%|██████| 14/14 [00:23<00:00,  1.68s/it]
# Evaluating (54 / 200 EPOCHS) (loss=0.95020) (dice score=0.43342): 100%|██████| 8/8 [00:03<00:00,  2.23it/s]
# Best record! [54] Test Loss: 0.943842, Dice score: 0.440436
# saved model
# Training (55 / 200 EPOCHS) (loss=0.97116) (dice score=0.46305): 100%|██████| 14/14 [00:23<00:00,  1.67s/it]
# Evaluating (55 / 200 EPOCHS) (loss=0.95067) (dice score=0.46036): 100%|██████| 8/8 [00:03<00:00,  2.23it/s]
# Training (56 / 200 EPOCHS) (loss=0.95801) (dice score=0.44101): 100%|██████| 14/14 [00:23<00:00,  1.67s/it]
# Evaluating (56 / 200 EPOCHS) (loss=0.95519) (dice score=0.42753): 100%|██████| 8/8 [00:03<00:00,  2.22it/s]
# Training (57 / 200 EPOCHS) (loss=0.95372) (dice score=0.41498): 100%|██████| 14/14 [00:23<00:00,  1.68s/it]
# Evaluating (57 / 200 EPOCHS) (loss=0.95315) (dice score=0.42097): 100%|██████| 8/8 [00:03<00:00,  2.22it/s]
# Training (58 / 200 EPOCHS) (loss=0.93900) (dice score=0.45940): 100%|██████| 14/14 [00:23<00:00,  1.68s/it]
# Evaluating (58 / 200 EPOCHS) (loss=0.94845) (dice score=0.45638): 100%|██████| 8/8 [00:03<00:00,  2.23it/s]
# Training (59 / 200 EPOCHS) (loss=0.88297) (dice score=0.40619): 100%|██████| 14/14 [00:23<00:00,  1.66s/it]
# Evaluating (59 / 200 EPOCHS) (loss=0.94288) (dice score=0.35501): 100%|██████| 8/8 [00:03<00:00,  2.24it/s]
# Best record! [59] Test Loss: 0.933578, Dice score: 0.372379
# saved model
# Training (60 / 200 EPOCHS) (loss=0.95171) (dice score=0.33831): 100%|██████| 14/14 [00:23<00:00,  1.65s/it]
# Evaluating (60 / 200 EPOCHS) (loss=0.93935) (dice score=0.32296): 100%|██████| 8/8 [00:03<00:00,  2.26it/s]
# Best record! [60] Test Loss: 0.927461, Dice score: 0.327383
# saved model
# Training (61 / 200 EPOCHS) (loss=0.92076) (dice score=0.37309): 100%|██████| 14/14 [00:23<00:00,  1.66s/it]
# Evaluating (61 / 200 EPOCHS) (loss=0.93686) (dice score=0.36729): 100%|██████| 8/8 [00:03<00:00,  2.24it/s]
# Best record! [61] Test Loss: 0.924025, Dice score: 0.368098
# saved model
# Training (62 / 200 EPOCHS) (loss=0.90513) (dice score=0.39968): 100%|██████| 14/14 [00:23<00:00,  1.65s/it]
# Evaluating (62 / 200 EPOCHS) (loss=0.92974) (dice score=0.39920): 100%|██████| 8/8 [00:03<00:00,  2.26it/s]
# Training (63 / 200 EPOCHS) (loss=0.93064) (dice score=0.37095): 100%|██████| 14/14 [00:23<00:00,  1.66s/it]
# Evaluating (63 / 200 EPOCHS) (loss=0.94628) (dice score=0.37910): 100%|██████| 8/8 [00:03<00:00,  2.26it/s]
# Training (64 / 200 EPOCHS) (loss=0.88646) (dice score=0.42755): 100%|██████| 14/14 [00:23<00:00,  1.66s/it]
# Evaluating (64 / 200 EPOCHS) (loss=0.92839) (dice score=0.42493): 100%|██████| 8/8 [00:03<00:00,  2.14it/s]
# Training (65 / 200 EPOCHS) (loss=0.90119) (dice score=0.45837): 100%|██████| 14/14 [00:24<00:00,  1.74s/it]
# Evaluating (65 / 200 EPOCHS) (loss=0.92950) (dice score=0.42563): 100%|██████| 8/8 [00:03<00:00,  2.06it/s]
# Best record! [65] Test Loss: 0.914273, Dice score: 0.435022
# saved model
# Training (66 / 200 EPOCHS) (loss=0.92118) (dice score=0.46317): 100%|██████| 14/14 [00:24<00:00,  1.75s/it]
# Evaluating (66 / 200 EPOCHS) (loss=0.92564) (dice score=0.46079): 100%|██████| 8/8 [00:03<00:00,  2.15it/s]
# Training (67 / 200 EPOCHS) (loss=0.85806) (dice score=0.45683): 100%|██████| 14/14 [00:23<00:00,  1.70s/it]
# Evaluating (67 / 200 EPOCHS) (loss=0.91523) (dice score=0.44743): 100%|██████| 8/8 [00:03<00:00,  2.20it/s]
# Training (68 / 200 EPOCHS) (loss=0.95328) (dice score=0.49509): 100%|██████| 14/14 [00:23<00:00,  1.68s/it]
# Evaluating (68 / 200 EPOCHS) (loss=0.92038) (dice score=0.47175): 100%|██████| 8/8 [00:03<00:00,  2.21it/s]
# Best record! [68] Test Loss: 0.907152, Dice score: 0.479689
# saved model
# Training (69 / 200 EPOCHS) (loss=0.91538) (dice score=0.52305): 100%|██████| 14/14 [00:23<00:00,  1.68s/it]
# Evaluating (69 / 200 EPOCHS) (loss=0.90925) (dice score=0.50158): 100%|██████| 8/8 [00:03<00:00,  2.22it/s]
# Best record! [69] Test Loss: 0.905521, Dice score: 0.507377
# saved model
# Training (70 / 200 EPOCHS) (loss=0.95679) (dice score=0.55073): 100%|██████| 14/14 [00:23<00:00,  1.68s/it]
# Evaluating (70 / 200 EPOCHS) (loss=0.90261) (dice score=0.53316): 100%|██████| 8/8 [00:03<00:00,  2.22it/s]
# Training (71 / 200 EPOCHS) (loss=0.91788) (dice score=0.56806): 100%|██████| 14/14 [00:23<00:00,  1.68s/it]
# Evaluating (71 / 200 EPOCHS) (loss=0.91155) (dice score=0.52151): 100%|██████| 8/8 [00:03<00:00,  2.24it/s]
# Training (72 / 200 EPOCHS) (loss=0.86656) (dice score=0.48882): 100%|██████| 14/14 [00:23<00:00,  1.67s/it]
# Evaluating (72 / 200 EPOCHS) (loss=0.89029) (dice score=0.49706): 100%|██████| 8/8 [00:03<00:00,  2.20it/s]
# Training (73 / 200 EPOCHS) (loss=0.88682) (dice score=0.53647): 100%|██████| 14/14 [00:23<00:00,  1.67s/it]
# Evaluating (73 / 200 EPOCHS) (loss=0.89505) (dice score=0.49498): 100%|██████| 8/8 [00:03<00:00,  2.23it/s]
# Training (74 / 200 EPOCHS) (loss=0.84649) (dice score=0.53219): 100%|██████| 14/14 [00:23<00:00,  1.68s/it]
# Evaluating (74 / 200 EPOCHS) (loss=0.89336) (dice score=0.51940): 100%|██████| 8/8 [00:03<00:00,  2.17it/s]
# Best record! [74] Test Loss: 0.905358, Dice score: 0.515179
# saved model
# Training (75 / 200 EPOCHS) (loss=0.93476) (dice score=0.53958): 100%|██████| 14/14 [00:23<00:00,  1.68s/it]
# Evaluating (75 / 200 EPOCHS) (loss=0.87673) (dice score=0.52967): 100%|██████| 8/8 [00:03<00:00,  2.19it/s]
# Best record! [75] Test Loss: 0.894781, Dice score: 0.527478
# saved model
# Training (76 / 200 EPOCHS) (loss=0.81810) (dice score=0.58658): 100%|██████| 14/14 [00:23<00:00,  1.67s/it]
# Evaluating (76 / 200 EPOCHS) (loss=0.88558) (dice score=0.53566): 100%|██████| 8/8 [00:03<00:00,  2.23it/s]
# Best record! [76] Test Loss: 0.881391, Dice score: 0.551541
# saved model
# Training (77 / 200 EPOCHS) (loss=0.87458) (dice score=0.54985): 100%|██████| 14/14 [00:23<00:00,  1.67s/it]
# Evaluating (77 / 200 EPOCHS) (loss=0.88151) (dice score=0.52667): 100%|██████| 8/8 [00:03<00:00,  2.24it/s]
# Training (78 / 200 EPOCHS) (loss=0.90621) (dice score=0.54341): 100%|██████| 14/14 [00:23<00:00,  1.67s/it]
# Evaluating (78 / 200 EPOCHS) (loss=0.87387) (dice score=0.51295): 100%|██████| 8/8 [00:03<00:00,  2.22it/s]
# Best record! [78] Test Loss: 0.874797, Dice score: 0.519377
# saved model
# Training (79 / 200 EPOCHS) (loss=0.78560) (dice score=0.56923): 100%|██████| 14/14 [00:23<00:00,  1.67s/it]
# Evaluating (79 / 200 EPOCHS) (loss=0.85352) (dice score=0.55930): 100%|██████| 8/8 [00:03<00:00,  2.25it/s]
# Best record! [79] Test Loss: 0.846756, Dice score: 0.559719
# saved model
# Training (80 / 200 EPOCHS) (loss=0.83408) (dice score=0.57877): 100%|██████| 14/14 [00:23<00:00,  1.66s/it]
# Evaluating (80 / 200 EPOCHS) (loss=0.85995) (dice score=0.56255): 100%|██████| 8/8 [00:03<00:00,  2.23it/s]
# Training (81 / 200 EPOCHS) (loss=0.88505) (dice score=0.60077): 100%|██████| 14/14 [00:23<00:00,  1.66s/it]
# Evaluating (81 / 200 EPOCHS) (loss=0.99143) (dice score=0.48182): 100%|██████| 8/8 [00:03<00:00,  2.22it/s]
# Training (82 / 200 EPOCHS) (loss=0.80572) (dice score=0.63366): 100%|██████| 14/14 [00:23<00:00,  1.67s/it]
# Evaluating (82 / 200 EPOCHS) (loss=0.85820) (dice score=0.59962): 100%|██████| 8/8 [00:03<00:00,  2.21it/s]
# Training (83 / 200 EPOCHS) (loss=0.81594) (dice score=0.63631): 100%|██████| 14/14 [00:23<00:00,  1.68s/it]
# Evaluating (83 / 200 EPOCHS) (loss=0.83558) (dice score=0.60077): 100%|██████| 8/8 [00:03<00:00,  2.09it/s]
# Training (84 / 200 EPOCHS) (loss=0.88554) (dice score=0.64931): 100%|██████| 14/14 [00:23<00:00,  1.68s/it]
# Evaluating (84 / 200 EPOCHS) (loss=0.84793) (dice score=0.61287): 100%|██████| 8/8 [00:03<00:00,  2.23it/s]
# Training (85 / 200 EPOCHS) (loss=0.80351) (dice score=0.62243): 100%|██████| 14/14 [00:23<00:00,  1.68s/it]
# Evaluating (85 / 200 EPOCHS) (loss=0.84031) (dice score=0.59684): 100%|██████| 8/8 [00:03<00:00,  2.21it/s]
# Training (86 / 200 EPOCHS) (loss=0.86030) (dice score=0.66029): 100%|██████| 14/14 [00:23<00:00,  1.68s/it]
# Evaluating (86 / 200 EPOCHS) (loss=0.83295) (dice score=0.60746): 100%|██████| 8/8 [00:03<00:00,  2.23it/s]
# Training (87 / 200 EPOCHS) (loss=0.85750) (dice score=0.63893): 100%|██████| 14/14 [00:23<00:00,  1.67s/it]
# Evaluating (87 / 200 EPOCHS) (loss=0.80252) (dice score=0.61040): 100%|██████| 8/8 [00:03<00:00,  2.21it/s]
# Best record! [87] Test Loss: 0.834824, Dice score: 0.613951
# saved model
# Training (88 / 200 EPOCHS) (loss=0.79149) (dice score=0.67316): 100%|██████| 14/14 [00:23<00:00,  1.66s/it]
# Evaluating (88 / 200 EPOCHS) (loss=0.81694) (dice score=0.62741): 100%|██████| 8/8 [00:03<00:00,  2.23it/s]
# Training (89 / 200 EPOCHS) (loss=0.82570) (dice score=0.65371): 100%|██████| 14/14 [00:23<00:00,  1.67s/it]
# Evaluating (89 / 200 EPOCHS) (loss=0.81247) (dice score=0.61071): 100%|██████| 8/8 [00:03<00:00,  2.21it/s]
# Training (90 / 200 EPOCHS) (loss=0.83393) (dice score=0.66804): 100%|██████| 14/14 [00:23<00:00,  1.67s/it]
# Evaluating (90 / 200 EPOCHS) (loss=0.82828) (dice score=0.63437): 100%|██████| 8/8 [00:03<00:00,  2.21it/s]
# Best record! [90] Test Loss: 0.811017, Dice score: 0.646054
# saved model
# Training (91 / 200 EPOCHS) (loss=0.73021) (dice score=0.65207): 100%|██████| 14/14 [00:23<00:00,  1.67s/it]
# Evaluating (91 / 200 EPOCHS) (loss=0.85177) (dice score=0.57109): 100%|██████| 8/8 [00:03<00:00,  2.21it/s]
# Training (92 / 200 EPOCHS) (loss=0.82542) (dice score=0.67004): 100%|██████| 14/14 [00:23<00:00,  1.68s/it]
# Evaluating (92 / 200 EPOCHS) (loss=0.76975) (dice score=0.63813): 100%|██████| 8/8 [00:03<00:00,  2.20it/s]
# Best record! [92] Test Loss: 0.785474, Dice score: 0.648498
# saved model
# Training (93 / 200 EPOCHS) (loss=0.73231) (dice score=0.69725): 100%|██████| 14/14 [00:23<00:00,  1.67s/it]
# Evaluating (93 / 200 EPOCHS) (loss=0.78989) (dice score=0.66283): 100%|██████| 8/8 [00:03<00:00,  2.22it/s]
# Training (94 / 200 EPOCHS) (loss=0.57479) (dice score=0.70529): 100%|██████| 14/14 [00:23<00:00,  1.67s/it]
# Evaluating (94 / 200 EPOCHS) (loss=0.76655) (dice score=0.65940): 100%|██████| 8/8 [00:03<00:00,  2.21it/s]
# Training (95 / 200 EPOCHS) (loss=0.82725) (dice score=0.70283): 100%|██████| 14/14 [00:23<00:00,  1.68s/it]
# Evaluating (95 / 200 EPOCHS) (loss=0.79392) (dice score=0.65845): 100%|██████| 8/8 [00:03<00:00,  2.23it/s]
# Training (96 / 200 EPOCHS) (loss=0.71876) (dice score=0.68208): 100%|██████| 14/14 [00:23<00:00,  1.67s/it]
# Evaluating (96 / 200 EPOCHS) (loss=0.74234) (dice score=0.64038): 100%|██████| 8/8 [00:03<00:00,  2.21it/s]
# Training (97 / 200 EPOCHS) (loss=0.74635) (dice score=0.73425): 100%|██████| 14/14 [00:23<00:00,  1.66s/it]
# Evaluating (97 / 200 EPOCHS) (loss=0.78471) (dice score=0.69539): 100%|██████| 8/8 [00:03<00:00,  2.20it/s]
# Best record! [97] Test Loss: 0.783961, Dice score: 0.707372
# saved model
# Training (98 / 200 EPOCHS) (loss=0.63406) (dice score=0.72570): 100%|██████| 14/14 [00:23<00:00,  1.67s/it]
# Evaluating (98 / 200 EPOCHS) (loss=0.77829) (dice score=0.65083): 100%|██████| 8/8 [00:03<00:00,  2.21it/s]
# Best record! [98] Test Loss: 0.783713, Dice score: 0.674378
# saved model
# Training (99 / 200 EPOCHS) (loss=0.73676) (dice score=0.69352): 100%|██████| 14/14 [00:23<00:00,  1.67s/it]
# Evaluating (99 / 200 EPOCHS) (loss=0.71716) (dice score=0.65698): 100%|██████| 8/8 [00:03<00:00,  2.22it/s]
# Training (100 / 200 EPOCHS) (loss=0.72189) (dice score=0.71241): 100%|█████| 14/14 [00:23<00:00,  1.68s/it]
# Evaluating (100 / 200 EPOCHS) (loss=0.75364) (dice score=0.64909): 100%|█████| 8/8 [00:03<00:00,  2.23it/s]
# Training (101 / 200 EPOCHS) (loss=0.75240) (dice score=0.75126): 100%|█████| 14/14 [00:23<00:00,  1.68s/it]
# Evaluating (101 / 200 EPOCHS) (loss=0.73461) (dice score=0.70071): 100%|█████| 8/8 [00:03<00:00,  2.22it/s]
# Best record! [101] Test Loss: 0.771284, Dice score: 0.712186
# saved model
# Training (102 / 200 EPOCHS) (loss=0.77348) (dice score=0.74466): 100%|█████| 14/14 [00:23<00:00,  1.66s/it]
# Evaluating (102 / 200 EPOCHS) (loss=0.82624) (dice score=0.65255): 100%|█████| 8/8 [00:03<00:00,  2.17it/s]
# Training (103 / 200 EPOCHS) (loss=0.64260) (dice score=0.75279): 100%|█████| 14/14 [00:23<00:00,  1.69s/it]
# Evaluating (103 / 200 EPOCHS) (loss=0.73263) (dice score=0.69970): 100%|█████| 8/8 [00:03<00:00,  2.21it/s]
# Best record! [103] Test Loss: 0.731659, Dice score: 0.715203
# saved model
# Training (104 / 200 EPOCHS) (loss=0.65333) (dice score=0.76797): 100%|█████| 14/14 [00:23<00:00,  1.70s/it]
# Evaluating (104 / 200 EPOCHS) (loss=0.75524) (dice score=0.68305): 100%|█████| 8/8 [00:03<00:00,  2.24it/s]
# Training (105 / 200 EPOCHS) (loss=0.70455) (dice score=0.76826): 100%|█████| 14/14 [00:23<00:00,  1.67s/it]
# Evaluating (105 / 200 EPOCHS) (loss=0.67126) (dice score=0.72552): 100%|█████| 8/8 [00:03<00:00,  2.24it/s]
# Best record! [105] Test Loss: 0.698926, Dice score: 0.738677
# saved model
# Training (106 / 200 EPOCHS) (loss=0.55172) (dice score=0.79126): 100%|█████| 14/14 [00:23<00:00,  1.68s/it]
# Evaluating (106 / 200 EPOCHS) (loss=0.69309) (dice score=0.73603): 100%|█████| 8/8 [00:03<00:00,  2.23it/s]
# Training (107 / 200 EPOCHS) (loss=0.57632) (dice score=0.77766): 100%|█████| 14/14 [00:23<00:00,  1.67s/it]
# Evaluating (107 / 200 EPOCHS) (loss=0.67698) (dice score=0.72941): 100%|█████| 8/8 [00:03<00:00,  2.23it/s]
# Training (108 / 200 EPOCHS) (loss=0.60630) (dice score=0.80919): 100%|█████| 14/14 [00:23<00:00,  1.68s/it]
# Evaluating (108 / 200 EPOCHS) (loss=0.69243) (dice score=0.75200): 100%|█████| 8/8 [00:03<00:00,  2.20it/s]
# Training (109 / 200 EPOCHS) (loss=0.67134) (dice score=0.79892): 100%|█████| 14/14 [00:23<00:00,  1.68s/it]
# Evaluating (109 / 200 EPOCHS) (loss=0.68564) (dice score=0.74528): 100%|█████| 8/8 [00:03<00:00,  2.19it/s]
# Training (110 / 200 EPOCHS) (loss=0.55834) (dice score=0.81322): 100%|█████| 14/14 [00:23<00:00,  1.68s/it]
# Evaluating (110 / 200 EPOCHS) (loss=0.63936) (dice score=0.75847): 100%|█████| 8/8 [00:03<00:00,  2.18it/s]
# Best record! [110] Test Loss: 0.681355, Dice score: 0.774234
# saved model
# Training (111 / 200 EPOCHS) (loss=0.40470) (dice score=0.81734): 100%|█████| 14/14 [00:23<00:00,  1.69s/it]
# Evaluating (111 / 200 EPOCHS) (loss=0.61342) (dice score=0.75570): 100%|█████| 8/8 [00:03<00:00,  2.18it/s]
# Training (112 / 200 EPOCHS) (loss=0.55376) (dice score=0.82965): 100%|█████| 14/14 [00:23<00:00,  1.68s/it]
# Evaluating (112 / 200 EPOCHS) (loss=0.63287) (dice score=0.76698): 100%|█████| 8/8 [00:03<00:00,  2.22it/s]
# Training (113 / 200 EPOCHS) (loss=0.53126) (dice score=0.83360): 100%|█████| 14/14 [00:23<00:00,  1.68s/it]
# Evaluating (113 / 200 EPOCHS) (loss=0.64451) (dice score=0.76076): 100%|█████| 8/8 [00:03<00:00,  2.19it/s]
# Training (114 / 200 EPOCHS) (loss=0.70320) (dice score=0.83937): 100%|█████| 14/14 [00:23<00:00,  1.68s/it]
# Evaluating (114 / 200 EPOCHS) (loss=0.62235) (dice score=0.77828): 100%|█████| 8/8 [00:03<00:00,  2.17it/s]
# Best record! [114] Test Loss: 0.676502, Dice score: 0.797098
# saved model
# Training (115 / 200 EPOCHS) (loss=0.52149) (dice score=0.83500): 100%|█████| 14/14 [00:23<00:00,  1.68s/it]
# Evaluating (115 / 200 EPOCHS) (loss=0.63846) (dice score=0.76619): 100%|█████| 8/8 [00:03<00:00,  2.22it/s]
# Training (116 / 200 EPOCHS) (loss=0.56845) (dice score=0.84320): 100%|█████| 14/14 [00:23<00:00,  1.68s/it]
# Evaluating (116 / 200 EPOCHS) (loss=0.61603) (dice score=0.77780): 100%|█████| 8/8 [00:03<00:00,  2.22it/s]
# Best record! [116] Test Loss: 0.663035, Dice score: 0.796972
# saved model
# Training (117 / 200 EPOCHS) (loss=0.54127) (dice score=0.84828): 100%|█████| 14/14 [00:23<00:00,  1.68s/it]
# Evaluating (117 / 200 EPOCHS) (loss=0.62459) (dice score=0.78006): 100%|█████| 8/8 [00:03<00:00,  2.23it/s]
# Best record! [117] Test Loss: 0.658933, Dice score: 0.800765
# saved model
# Training (118 / 200 EPOCHS) (loss=0.47487) (dice score=0.84293): 100%|█████| 14/14 [00:23<00:00,  1.70s/it]
# Evaluating (118 / 200 EPOCHS) (loss=0.60378) (dice score=0.78280): 100%|█████| 8/8 [00:03<00:00,  2.19it/s]
# Best record! [118] Test Loss: 0.632405, Dice score: 0.799884
# saved model
# Training (119 / 200 EPOCHS) (loss=0.47497) (dice score=0.86106): 100%|█████| 14/14 [00:23<00:00,  1.70s/it]
# Evaluating (119 / 200 EPOCHS) (loss=0.57638) (dice score=0.79673): 100%|█████| 8/8 [00:03<00:00,  2.22it/s]
# Training (120 / 200 EPOCHS) (loss=0.60485) (dice score=0.84279): 100%|█████| 14/14 [00:23<00:00,  1.68s/it]
# Evaluating (120 / 200 EPOCHS) (loss=0.58128) (dice score=0.78549): 100%|█████| 8/8 [00:03<00:00,  2.21it/s]
# Best record! [120] Test Loss: 0.623572, Dice score: 0.802359
# saved model
# Training (121 / 200 EPOCHS) (loss=0.54790) (dice score=0.84932): 100%|█████| 14/14 [00:23<00:00,  1.69s/it]
# Evaluating (121 / 200 EPOCHS) (loss=0.60372) (dice score=0.78412): 100%|█████| 8/8 [00:03<00:00,  2.21it/s]
# Training (122 / 200 EPOCHS) (loss=0.56734) (dice score=0.86185): 100%|█████| 14/14 [00:23<00:00,  1.68s/it]
# Evaluating (122 / 200 EPOCHS) (loss=0.61925) (dice score=0.79136): 100%|█████| 8/8 [00:03<00:00,  2.23it/s]
# Training (123 / 200 EPOCHS) (loss=0.45451) (dice score=0.87155): 100%|█████| 14/14 [00:23<00:00,  1.69s/it]
# Evaluating (123 / 200 EPOCHS) (loss=0.54434) (dice score=0.79634): 100%|█████| 8/8 [00:03<00:00,  2.18it/s]
# Training (124 / 200 EPOCHS) (loss=0.43980) (dice score=0.87550): 100%|█████| 14/14 [00:23<00:00,  1.69s/it]
# Evaluating (124 / 200 EPOCHS) (loss=0.51429) (dice score=0.80194): 100%|█████| 8/8 [00:03<00:00,  2.21it/s]
# Training (125 / 200 EPOCHS) (loss=0.36547) (dice score=0.89003): 100%|█████| 14/14 [00:23<00:00,  1.69s/it]
# Evaluating (125 / 200 EPOCHS) (loss=0.54277) (dice score=0.81186): 100%|█████| 8/8 [00:03<00:00,  2.21it/s]
# Training (126 / 200 EPOCHS) (loss=0.37474) (dice score=0.88192): 100%|█████| 14/14 [00:23<00:00,  1.68s/it]
# Evaluating (126 / 200 EPOCHS) (loss=0.57199) (dice score=0.79410): 100%|█████| 8/8 [00:03<00:00,  2.19it/s]
# Training (127 / 200 EPOCHS) (loss=0.46305) (dice score=0.89018): 100%|█████| 14/14 [00:23<00:00,  1.68s/it]
# Evaluating (127 / 200 EPOCHS) (loss=0.57000) (dice score=0.81279): 100%|█████| 8/8 [00:03<00:00,  2.22it/s]
# Training (128 / 200 EPOCHS) (loss=0.28875) (dice score=0.89379): 100%|█████| 14/14 [00:23<00:00,  1.68s/it]
# Evaluating (128 / 200 EPOCHS) (loss=0.50283) (dice score=0.82620): 100%|█████| 8/8 [00:03<00:00,  2.23it/s]
# Best record! [128] Test Loss: 0.588423, Dice score: 0.846324
# saved model
# Training (129 / 200 EPOCHS) (loss=0.43677) (dice score=0.89174): 100%|█████| 14/14 [00:23<00:00,  1.69s/it]
# Evaluating (129 / 200 EPOCHS) (loss=0.52026) (dice score=0.81129): 100%|█████| 8/8 [00:03<00:00,  2.19it/s]
# Training (130 / 200 EPOCHS) (loss=0.27057) (dice score=0.90164): 100%|█████| 14/14 [00:23<00:00,  1.68s/it]
# Evaluating (130 / 200 EPOCHS) (loss=0.50396) (dice score=0.82573): 100%|█████| 8/8 [00:03<00:00,  2.23it/s]
# Training (131 / 200 EPOCHS) (loss=0.38409) (dice score=0.90836): 100%|█████| 14/14 [00:23<00:00,  1.68s/it]
# Evaluating (131 / 200 EPOCHS) (loss=0.50473) (dice score=0.83238): 100%|█████| 8/8 [00:03<00:00,  2.23it/s]
# Best record! [131] Test Loss: 0.583653, Dice score: 0.855335
# saved model
# Training (132 / 200 EPOCHS) (loss=0.29600) (dice score=0.89470): 100%|█████| 14/14 [00:23<00:00,  1.68s/it]
# Evaluating (132 / 200 EPOCHS) (loss=0.50954) (dice score=0.82234): 100%|█████| 8/8 [00:03<00:00,  2.24it/s]
# Training (133 / 200 EPOCHS) (loss=0.58937) (dice score=0.88446): 100%|█████| 14/14 [00:23<00:00,  1.68s/it]
# Evaluating (133 / 200 EPOCHS) (loss=0.47798) (dice score=0.80916): 100%|█████| 8/8 [00:03<00:00,  2.23it/s]
# Training (134 / 200 EPOCHS) (loss=0.30436) (dice score=0.89896): 100%|█████| 14/14 [00:23<00:00,  1.67s/it]
# Evaluating (134 / 200 EPOCHS) (loss=0.44800) (dice score=0.81944): 100%|█████| 8/8 [00:03<00:00,  2.23it/s]
# Training (135 / 200 EPOCHS) (loss=0.25893) (dice score=0.90689): 100%|█████| 14/14 [00:23<00:00,  1.68s/it]
# Evaluating (135 / 200 EPOCHS) (loss=0.50823) (dice score=0.82490): 100%|█████| 8/8 [00:03<00:00,  2.23it/s]
# Training (136 / 200 EPOCHS) (loss=0.43271) (dice score=0.91029): 100%|█████| 14/14 [00:23<00:00,  1.68s/it]
# Evaluating (136 / 200 EPOCHS) (loss=0.49623) (dice score=0.82279): 100%|█████| 8/8 [00:03<00:00,  2.22it/s]
# Training (137 / 200 EPOCHS) (loss=0.42221) (dice score=0.90514): 100%|█████| 14/14 [00:23<00:00,  1.68s/it]
# Evaluating (137 / 200 EPOCHS) (loss=0.48425) (dice score=0.83362): 100%|█████| 8/8 [00:03<00:00,  2.23it/s]
# Best record! [137] Test Loss: 0.562671, Dice score: 0.853657
# saved model
# Training (138 / 200 EPOCHS) (loss=0.35092) (dice score=0.91145): 100%|█████| 14/14 [00:23<00:00,  1.69s/it]
# Evaluating (138 / 200 EPOCHS) (loss=0.48443) (dice score=0.82128): 100%|█████| 8/8 [00:03<00:00,  2.22it/s]
# Training (139 / 200 EPOCHS) (loss=0.31780) (dice score=0.92302): 100%|█████| 14/14 [00:23<00:00,  1.68s/it]
# Evaluating (139 / 200 EPOCHS) (loss=0.49174) (dice score=0.84412): 100%|█████| 8/8 [00:03<00:00,  2.21it/s]
# Best record! [139] Test Loss: 0.555207, Dice score: 0.867759
# saved model
# Training (140 / 200 EPOCHS) (loss=0.15517) (dice score=0.92459): 100%|█████| 14/14 [00:23<00:00,  1.69s/it]
# Evaluating (140 / 200 EPOCHS) (loss=0.47120) (dice score=0.84559): 100%|█████| 8/8 [00:03<00:00,  2.22it/s]
# Best record! [140] Test Loss: 0.535145, Dice score: 0.870541
# saved model
# Training (141 / 200 EPOCHS) (loss=0.25366) (dice score=0.91742): 100%|█████| 14/14 [00:23<00:00,  1.70s/it]
# Evaluating (141 / 200 EPOCHS) (loss=0.45086) (dice score=0.83579): 100%|█████| 8/8 [00:03<00:00,  2.17it/s]
# Training (142 / 200 EPOCHS) (loss=0.36780) (dice score=0.92469): 100%|█████| 14/14 [00:23<00:00,  1.69s/it]
# Evaluating (142 / 200 EPOCHS) (loss=0.45678) (dice score=0.84578): 100%|█████| 8/8 [00:03<00:00,  2.22it/s]
# Training (143 / 200 EPOCHS) (loss=0.22087) (dice score=0.93169): 100%|█████| 14/14 [00:23<00:00,  1.68s/it]
# Evaluating (143 / 200 EPOCHS) (loss=0.42752) (dice score=0.84908): 100%|█████| 8/8 [00:03<00:00,  2.20it/s]
# Training (144 / 200 EPOCHS) (loss=0.26994) (dice score=0.93524): 100%|█████| 14/14 [00:23<00:00,  1.69s/it]
# Evaluating (144 / 200 EPOCHS) (loss=0.45867) (dice score=0.85269): 100%|█████| 8/8 [00:03<00:00,  2.21it/s]
# Training (145 / 200 EPOCHS) (loss=0.17955) (dice score=0.93900): 100%|█████| 14/14 [00:23<00:00,  1.68s/it]
# Evaluating (145 / 200 EPOCHS) (loss=0.42491) (dice score=0.85236): 100%|█████| 8/8 [00:03<00:00,  2.19it/s]
# Training (146 / 200 EPOCHS) (loss=0.20907) (dice score=0.93932): 100%|█████| 14/14 [00:23<00:00,  1.68s/it]
# Evaluating (146 / 200 EPOCHS) (loss=0.43345) (dice score=0.85967): 100%|█████| 8/8 [00:03<00:00,  2.23it/s]
# Best record! [146] Test Loss: 0.520039, Dice score: 0.884131
# saved model
# Training (147 / 200 EPOCHS) (loss=0.19989) (dice score=0.94030): 100%|█████| 14/14 [00:23<00:00,  1.69s/it]
# Evaluating (147 / 200 EPOCHS) (loss=0.44348) (dice score=0.85358): 100%|█████| 8/8 [00:03<00:00,  2.23it/s]
# Training (148 / 200 EPOCHS) (loss=0.36487) (dice score=0.94147): 100%|█████| 14/14 [00:23<00:00,  1.67s/it]
# Evaluating (148 / 200 EPOCHS) (loss=0.43118) (dice score=0.84483): 100%|█████| 8/8 [00:03<00:00,  2.23it/s]
# Training (149 / 200 EPOCHS) (loss=0.17857) (dice score=0.93940): 100%|█████| 14/14 [00:23<00:00,  1.68s/it]
# Evaluating (149 / 200 EPOCHS) (loss=0.41945) (dice score=0.86378): 100%|█████| 8/8 [00:03<00:00,  2.20it/s]
# Best record! [149] Test Loss: 0.494884, Dice score: 0.887390
# saved model
# Training (150 / 200 EPOCHS) (loss=0.23883) (dice score=0.93497): 100%|█████| 14/14 [00:23<00:00,  1.69s/it]
# Evaluating (150 / 200 EPOCHS) (loss=0.40271) (dice score=0.85553): 100%|█████| 8/8 [00:03<00:00,  2.21it/s]
# Training (151 / 200 EPOCHS) (loss=0.22210) (dice score=0.93132): 100%|█████| 14/14 [00:23<00:00,  1.68s/it]
# Evaluating (151 / 200 EPOCHS) (loss=0.42761) (dice score=0.84679): 100%|█████| 8/8 [00:03<00:00,  2.21it/s]
# Training (152 / 200 EPOCHS) (loss=0.20561) (dice score=0.93588): 100%|█████| 14/14 [00:23<00:00,  1.67s/it]
# Evaluating (152 / 200 EPOCHS) (loss=0.43649) (dice score=0.85311): 100%|█████| 8/8 [00:03<00:00,  2.20it/s]
# Training (153 / 200 EPOCHS) (loss=0.24348) (dice score=0.93450): 100%|█████| 14/14 [00:23<00:00,  1.68s/it]
# Evaluating (153 / 200 EPOCHS) (loss=0.41291) (dice score=0.85476): 100%|█████| 8/8 [00:03<00:00,  2.22it/s]
# Training (154 / 200 EPOCHS) (loss=0.18199) (dice score=0.94017): 100%|█████| 14/14 [00:23<00:00,  1.67s/it]
# Evaluating (154 / 200 EPOCHS) (loss=0.40503) (dice score=0.86278): 100%|█████| 8/8 [00:03<00:00,  2.19it/s]
# Training (155 / 200 EPOCHS) (loss=0.22684) (dice score=0.94101): 100%|█████| 14/14 [00:23<00:00,  1.68s/it]
# Evaluating (155 / 200 EPOCHS) (loss=0.38665) (dice score=0.85939): 100%|█████| 8/8 [00:03<00:00,  2.20it/s]
# Training (156 / 200 EPOCHS) (loss=0.14330) (dice score=0.94452): 100%|█████| 14/14 [00:23<00:00,  1.67s/it]
# Evaluating (156 / 200 EPOCHS) (loss=0.41677) (dice score=0.85756): 100%|█████| 8/8 [00:03<00:00,  2.20it/s]
# Training (157 / 200 EPOCHS) (loss=0.26544) (dice score=0.94880): 100%|█████| 14/14 [00:23<00:00,  1.68s/it]
# Evaluating (157 / 200 EPOCHS) (loss=0.44502) (dice score=0.85019): 100%|█████| 8/8 [00:03<00:00,  2.25it/s]
# Training (158 / 200 EPOCHS) (loss=0.21969) (dice score=0.94603): 100%|█████| 14/14 [00:23<00:00,  1.67s/it]
# Evaluating (158 / 200 EPOCHS) (loss=0.40011) (dice score=0.86274): 100%|█████| 8/8 [00:03<00:00,  2.22it/s]
# Training (159 / 200 EPOCHS) (loss=0.12838) (dice score=0.94400): 100%|█████| 14/14 [00:23<00:00,  1.67s/it]
# Evaluating (159 / 200 EPOCHS) (loss=0.40110) (dice score=0.86557): 100%|█████| 8/8 [00:03<00:00,  2.21it/s]
# Best record! [159] Test Loss: 0.485438, Dice score: 0.890602
# saved model
# Training (160 / 200 EPOCHS) (loss=0.15482) (dice score=0.94541): 100%|█████| 14/14 [00:23<00:00,  1.68s/it]
# Evaluating (160 / 200 EPOCHS) (loss=0.40732) (dice score=0.86253): 100%|█████| 8/8 [00:03<00:00,  2.24it/s]
# Training (161 / 200 EPOCHS) (loss=0.10746) (dice score=0.94611): 100%|█████| 14/14 [00:23<00:00,  1.67s/it]
# Evaluating (161 / 200 EPOCHS) (loss=0.39603) (dice score=0.86231): 100%|█████| 8/8 [00:03<00:00,  2.23it/s]
# Training (162 / 200 EPOCHS) (loss=0.26027) (dice score=0.95153): 100%|█████| 14/14 [00:23<00:00,  1.67s/it]
# Evaluating (162 / 200 EPOCHS) (loss=0.43364) (dice score=0.86756): 100%|█████| 8/8 [00:03<00:00,  2.20it/s]
# Training (163 / 200 EPOCHS) (loss=0.17501) (dice score=0.95027): 100%|█████| 14/14 [00:23<00:00,  1.67s/it]
# Evaluating (163 / 200 EPOCHS) (loss=0.40235) (dice score=0.86537): 100%|█████| 8/8 [00:03<00:00,  2.22it/s]
# Training (164 / 200 EPOCHS) (loss=0.12761) (dice score=0.95444): 100%|█████| 14/14 [00:23<00:00,  1.67s/it]
# Evaluating (164 / 200 EPOCHS) (loss=0.40429) (dice score=0.86481): 100%|█████| 8/8 [00:03<00:00,  2.23it/s]
# Training (165 / 200 EPOCHS) (loss=0.19396) (dice score=0.95540): 100%|█████| 14/14 [00:23<00:00,  1.67s/it]
# Evaluating (165 / 200 EPOCHS) (loss=0.40008) (dice score=0.86921): 100%|█████| 8/8 [00:03<00:00,  2.23it/s]
# Training (166 / 200 EPOCHS) (loss=0.15605) (dice score=0.95212): 100%|█████| 14/14 [00:23<00:00,  1.67s/it]
# Evaluating (166 / 200 EPOCHS) (loss=0.39968) (dice score=0.86932): 100%|█████| 8/8 [00:03<00:00,  2.22it/s]
# Training (167 / 200 EPOCHS) (loss=0.12261) (dice score=0.94888): 100%|█████| 14/14 [00:23<00:00,  1.67s/it]
# Evaluating (167 / 200 EPOCHS) (loss=0.36269) (dice score=0.86157): 100%|█████| 8/8 [00:03<00:00,  2.21it/s]
# Training (168 / 200 EPOCHS) (loss=0.14262) (dice score=0.94993): 100%|█████| 14/14 [00:23<00:00,  1.67s/it]
# Evaluating (168 / 200 EPOCHS) (loss=0.40634) (dice score=0.86834): 100%|█████| 8/8 [00:03<00:00,  2.23it/s]
# Best record! [168] Test Loss: 0.471917, Dice score: 0.893748
# saved model
# Training (169 / 200 EPOCHS) (loss=0.16322) (dice score=0.95333): 100%|█████| 14/14 [00:23<00:00,  1.67s/it]
# Evaluating (169 / 200 EPOCHS) (loss=0.38939) (dice score=0.86778): 100%|█████| 8/8 [00:03<00:00,  2.21it/s]
# Training (170 / 200 EPOCHS) (loss=0.12441) (dice score=0.95229): 100%|█████| 14/14 [00:23<00:00,  1.67s/it]
# Evaluating (170 / 200 EPOCHS) (loss=0.39263) (dice score=0.86846): 100%|█████| 8/8 [00:03<00:00,  2.22it/s]
# Training (171 / 200 EPOCHS) (loss=0.15093) (dice score=0.95069): 100%|█████| 14/14 [00:23<00:00,  1.67s/it]
# Evaluating (171 / 200 EPOCHS) (loss=0.36283) (dice score=0.86807): 100%|█████| 8/8 [00:03<00:00,  2.23it/s]
# Training (172 / 200 EPOCHS) (loss=0.11468) (dice score=0.95324): 100%|█████| 14/14 [00:23<00:00,  1.67s/it]
# Evaluating (172 / 200 EPOCHS) (loss=0.38622) (dice score=0.86525): 100%|█████| 8/8 [00:03<00:00,  2.22it/s]
# Training (173 / 200 EPOCHS) (loss=0.09311) (dice score=0.95622): 100%|█████| 14/14 [00:23<00:00,  1.68s/it]
# Evaluating (173 / 200 EPOCHS) (loss=0.37331) (dice score=0.87139): 100%|█████| 8/8 [00:03<00:00,  2.18it/s]
# Training (174 / 200 EPOCHS) (loss=0.12253) (dice score=0.95879): 100%|█████| 14/14 [00:23<00:00,  1.68s/it]
# Evaluating (174 / 200 EPOCHS) (loss=0.38193) (dice score=0.86780): 100%|█████| 8/8 [00:03<00:00,  2.17it/s]
# Training (175 / 200 EPOCHS) (loss=0.12553) (dice score=0.95839): 100%|█████| 14/14 [00:23<00:00,  1.69s/it]
# Evaluating (175 / 200 EPOCHS) (loss=0.36003) (dice score=0.87579): 100%|█████| 8/8 [00:03<00:00,  2.15it/s]
# Best record! [175] Test Loss: 0.461281, Dice score: 0.901321
# saved model
# Training (176 / 200 EPOCHS) (loss=0.14179) (dice score=0.96079): 100%|█████| 14/14 [00:23<00:00,  1.68s/it]
# Evaluating (176 / 200 EPOCHS) (loss=0.39274) (dice score=0.87125): 100%|█████| 8/8 [00:03<00:00,  2.16it/s]
# Training (177 / 200 EPOCHS) (loss=0.08868) (dice score=0.96015): 100%|█████| 14/14 [00:23<00:00,  1.67s/it]
# Evaluating (177 / 200 EPOCHS) (loss=0.38149) (dice score=0.87748): 100%|█████| 8/8 [00:03<00:00,  2.22it/s]
# Best record! [177] Test Loss: 0.461271, Dice score: 0.903899
# saved model
# Training (178 / 200 EPOCHS) (loss=0.17546) (dice score=0.95626): 100%|█████| 14/14 [00:23<00:00,  1.69s/it]
# Evaluating (178 / 200 EPOCHS) (loss=0.37229) (dice score=0.86415): 100%|█████| 8/8 [00:03<00:00,  2.21it/s]
# Training (179 / 200 EPOCHS) (loss=0.13936) (dice score=0.95739): 100%|█████| 14/14 [00:23<00:00,  1.68s/it]
# Evaluating (179 / 200 EPOCHS) (loss=0.39433) (dice score=0.87449): 100%|█████| 8/8 [00:03<00:00,  2.22it/s]
# Training (180 / 200 EPOCHS) (loss=0.11380) (dice score=0.95394): 100%|█████| 14/14 [00:23<00:00,  1.69s/it]
# Evaluating (180 / 200 EPOCHS) (loss=0.38779) (dice score=0.86438): 100%|█████| 8/8 [00:03<00:00,  2.22it/s]
# Training (181 / 200 EPOCHS) (loss=0.10572) (dice score=0.95886): 100%|█████| 14/14 [00:23<00:00,  1.68s/it]
# Evaluating (181 / 200 EPOCHS) (loss=0.37589) (dice score=0.87201): 100%|█████| 8/8 [00:03<00:00,  2.21it/s]
# Training (182 / 200 EPOCHS) (loss=0.14120) (dice score=0.95814): 100%|█████| 14/14 [00:23<00:00,  1.69s/it]
# Evaluating (182 / 200 EPOCHS) (loss=0.37337) (dice score=0.87245): 100%|█████| 8/8 [00:03<00:00,  2.22it/s]
# Training (183 / 200 EPOCHS) (loss=0.10188) (dice score=0.95880): 100%|█████| 14/14 [00:23<00:00,  1.68s/it]
# Evaluating (183 / 200 EPOCHS) (loss=0.37235) (dice score=0.86906): 100%|█████| 8/8 [00:03<00:00,  2.22it/s]
# Training (184 / 200 EPOCHS) (loss=0.10552) (dice score=0.96000): 100%|█████| 14/14 [00:23<00:00,  1.69s/it]
# Evaluating (184 / 200 EPOCHS) (loss=0.35768) (dice score=0.87193): 100%|█████| 8/8 [00:03<00:00,  2.22it/s]
# Training (185 / 200 EPOCHS) (loss=0.19637) (dice score=0.96083): 100%|█████| 14/14 [00:23<00:00,  1.68s/it]
# Evaluating (185 / 200 EPOCHS) (loss=0.36580) (dice score=0.87388): 100%|█████| 8/8 [00:03<00:00,  2.22it/s]
# Training (186 / 200 EPOCHS) (loss=0.10557) (dice score=0.96228): 100%|█████| 14/14 [00:23<00:00,  1.69s/it]
# Evaluating (186 / 200 EPOCHS) (loss=0.38081) (dice score=0.87480): 100%|█████| 8/8 [00:03<00:00,  2.23it/s]
# Training (187 / 200 EPOCHS) (loss=0.08074) (dice score=0.96252): 100%|█████| 14/14 [00:23<00:00,  1.67s/it]
# Evaluating (187 / 200 EPOCHS) (loss=0.35820) (dice score=0.87694): 100%|█████| 8/8 [00:03<00:00,  2.23it/s]
# Training (188 / 200 EPOCHS) (loss=0.07401) (dice score=0.96265): 100%|█████| 14/14 [00:23<00:00,  1.68s/it]
# Evaluating (188 / 200 EPOCHS) (loss=0.36520) (dice score=0.87614): 100%|█████| 8/8 [00:03<00:00,  2.23it/s]
# Training (189 / 200 EPOCHS) (loss=0.11838) (dice score=0.96176): 100%|█████| 14/14 [00:23<00:00,  1.69s/it]
# Evaluating (189 / 200 EPOCHS) (loss=0.37105) (dice score=0.87443): 100%|█████| 8/8 [00:03<00:00,  2.21it/s]
# Training (190 / 200 EPOCHS) (loss=0.08505) (dice score=0.96316): 100%|█████| 14/14 [00:23<00:00,  1.68s/it]
# Evaluating (190 / 200 EPOCHS) (loss=0.36508) (dice score=0.87203): 100%|█████| 8/8 [00:03<00:00,  2.23it/s]
# Training (191 / 200 EPOCHS) (loss=0.12874) (dice score=0.96359): 100%|█████| 14/14 [00:23<00:00,  1.69s/it]
# Evaluating (191 / 200 EPOCHS) (loss=0.35763) (dice score=0.87548): 100%|█████| 8/8 [00:03<00:00,  2.22it/s]
# Training (192 / 200 EPOCHS) (loss=0.09370) (dice score=0.96268): 100%|█████| 14/14 [00:23<00:00,  1.68s/it]
# Evaluating (192 / 200 EPOCHS) (loss=0.35689) (dice score=0.87803): 100%|█████| 8/8 [00:03<00:00,  2.22it/s]
# Best record! [192] Test Loss: 0.454067, Dice score: 0.904257
# saved model
# Training (193 / 200 EPOCHS) (loss=0.07989) (dice score=0.96347): 100%|█████| 14/14 [00:23<00:00,  1.68s/it]
# Evaluating (193 / 200 EPOCHS) (loss=0.36791) (dice score=0.87051): 100%|█████| 8/8 [00:03<00:00,  2.21it/s]
# Training (194 / 200 EPOCHS) (loss=0.11489) (dice score=0.96282): 100%|█████| 14/14 [00:23<00:00,  1.68s/it]
# Evaluating (194 / 200 EPOCHS) (loss=0.37311) (dice score=0.87463): 100%|█████| 8/8 [00:03<00:00,  2.21it/s]
# Training (195 / 200 EPOCHS) (loss=0.11033) (dice score=0.96040): 100%|█████| 14/14 [00:23<00:00,  1.67s/it]
# Evaluating (195 / 200 EPOCHS) (loss=0.38564) (dice score=0.87217): 100%|█████| 8/8 [00:03<00:00,  2.22it/s]
# Training (196 / 200 EPOCHS) (loss=0.10121) (dice score=0.96189): 100%|█████| 14/14 [00:23<00:00,  1.67s/it]
# Evaluating (196 / 200 EPOCHS) (loss=0.35145) (dice score=0.87493): 100%|█████| 8/8 [00:03<00:00,  2.21it/s]
# Training (197 / 200 EPOCHS) (loss=0.09555) (dice score=0.96178): 100%|█████| 14/14 [00:23<00:00,  1.67s/it]
# Evaluating (197 / 200 EPOCHS) (loss=0.34526) (dice score=0.87039): 100%|█████| 8/8 [00:03<00:00,  2.23it/s]
# Training (198 / 200 EPOCHS) (loss=0.15226) (dice score=0.96173): 100%|█████| 14/14 [00:23<00:00,  1.68s/it]
# Evaluating (198 / 200 EPOCHS) (loss=0.37006) (dice score=0.87962): 100%|█████| 8/8 [00:03<00:00,  2.23it/s]
# Best record! [198] Test Loss: 0.443301, Dice score: 0.906004
# saved model
# Training (199 / 200 EPOCHS) (loss=0.14324) (dice score=0.95942): 100%|█████| 14/14 [00:23<00:00,  1.67s/it]
# Evaluating (199 / 200 EPOCHS) (loss=0.38899) (dice score=0.87124): 100%|█████| 8/8 [00:03<00:00,  2.23it/s]
# Training (200 / 200 EPOCHS) (loss=0.12078) (dice score=0.96390): 100%|█████| 14/14 [00:23<00:00,  1.68s/it]
# Evaluating (200 / 200 EPOCHS) (loss=0.35778) (dice score=0.87750): 100%|█████| 8/8 [00:03<00:00,  2.21it/s]

# %%
print(f"train completed, best_metric: {best_metric:.4f} at epoch: {best_epoch}")
# Out:
# train completed, best_metric: 0.4433 at epoch: 198

# %% [markdown]
# 11. learning curve

# %%
epochs = [i for i in range(len(losses['train']))]
train_loss = losses['train']
val_loss = losses['val']
train_dice = dice_scores['train']
val_dice = dice_scores['val']

fig , ax = plt.subplots(1,2)
fig.set_size_inches(12,6)

ax[0].plot(epochs , train_loss , 'g-o' , label = 'Training Loss')
ax[0].plot(epochs , val_loss , 'r-o' , label = 'Validation Loss')
ax[0].set_title('Training & Validation Loss')
ax[0].legend()
ax[0].set_xlabel("Epochs")
ax[0].set_ylabel("Loss")

ax[1].plot(epochs , train_dice , 'go-' , label = 'Training Dice score')
ax[1].plot(epochs , val_dice , 'ro-' , label = 'Validation Dice score')
ax[1].set_title('Training & Validation Dice score')
ax[1].legend()
ax[1].set_xlabel("Epochs")
ax[1].set_ylabel("Dice score")

plt.show()

# %% [markdown]
# 12. visualize the result

# %%
pred_dict = {'input':[], 'target':[], 'output':[]}

if MODEL_SAVE:
    model.load_state_dict(torch.load(os.path.join(MODEL_SAVE_PATH, model_name)))

model.to('cpu')
model.eval()
with torch.no_grad():
    for i, data in enumerate(test_loader):
        img, target = data["image"].cpu(), data["label"].cpu()

        output = model(img).detach().cpu()
        output = torch.argmax(output, dim=1)
        
        pred_dict['input'].append(img)
        pred_dict['target'].append(target)
        pred_dict['output'].append(output)
        
        if i > 10:
            break

# %%
ncols, nrows = 10, 3*3
interval = int(IMAGE_SIZE[-1]//(ncols*nrows/3))
fig, axes = plt.subplots(ncols=ncols, nrows=nrows, figsize=(ncols,nrows))
cnt1, cnt2, cnt3 = 0, 0, 0
for i in range(nrows):
    for j in range(ncols):
        if i%3 == 0:
            axes[i,j].imshow(pred_dict['input'][0][0,0,:,:,cnt1], cmap='gray')
            cnt1+=interval
        elif i%3 == 1:
            axes[i,j].imshow(pred_dict['target'][0][0,0,:,:,cnt2], cmap='gray')
            cnt2+=interval
        else:
            axes[i,j].imshow(pred_dict['output'][0][0,:,:,cnt3], cmap='gray')
            cnt3+=interval
        axes[i,j].axis('off')
plt.subplots_adjust(wspace=0, hspace=0, left=0, right=1, bottom=0, top=1)
plt.show()
