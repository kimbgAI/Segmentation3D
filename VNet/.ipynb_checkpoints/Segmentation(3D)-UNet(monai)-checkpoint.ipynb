# %%
import torch
import torchvision as tv
import torch.nn as nn
from torch.nn import functional as F
import time
from PIL import Image
import PIL
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os
import random
from torchsummary import summary as model_summary
import glob
import nibabel as nib
import skimage
import sklearn
from sklearn import model_selection
import monai

from monai.networks.nets import UNet
from monai.networks.layers import Norm
from monai.transforms import (
    Compose,
    EnsureChannelFirstd,
    LoadImage,
    LoadImaged,
    Orientationd,
    Rand3DElasticd,
    RandAffined,
    Spacingd,
    Resized,
    NormalizeIntensityd,
    ToTensord,
    AsDiscrete,
)
from monai.config import print_config
from typing import Optional

from tqdm import tqdm
# from tqdm.notebook import tqdm

print(f'torch.cuda.is_available(): {torch.cuda.is_available()}')
print(f'torch.cuda.get_device_name(0): {torch.cuda.get_device_name(0)}')
print(f'torch.version.cuda: {torch.version.cuda}')
print(f'torch.cuda.device_count(): {torch.cuda.device_count()}')
print()
monai.config.print_config()
# Out:
# torch.cuda.is_available(): True
# torch.cuda.get_device_name(0): NVIDIA GeForce RTX 3060
# torch.version.cuda: 11.3
# torch.cuda.device_count(): 1
#
# MONAI version: 1.0.0
# Numpy version: 1.22.3
# Pytorch version: 1.12.1
# MONAI flags: HAS_EXT = False, USE_COMPILED = False, USE_META_DICT = False
# MONAI rev id: 170093375ce29267e45681fcec09dfa856e1d7e7
# MONAI __file__: /home/kimbg/anaconda3/envs/test1/lib/python3.10/site-packages/monai/__init__.py
#
# Optional dependencies:
# Pytorch Ignite version: NOT INSTALLED or UNKNOWN VERSION.
# Nibabel version: 4.0.2
# scikit-image version: 0.19.3
# Pillow version: 9.2.0
# Tensorboard version: NOT INSTALLED or UNKNOWN VERSION.
# gdown version: NOT INSTALLED or UNKNOWN VERSION.
# TorchVision version: 0.13.1
# tqdm version: 4.64.0
# lmdb version: NOT INSTALLED or UNKNOWN VERSION.
# psutil version: 5.9.0
# pandas version: 1.5.1
# einops version: 0.5.0
# transformers version: NOT INSTALLED or UNKNOWN VERSION.
# mlflow version: NOT INSTALLED or UNKNOWN VERSION.
# pynrrd version: NOT INSTALLED or UNKNOWN VERSION.
#
# For details about installing the optional dependencies, please visit:
#     https://docs.monai.io/en/latest/installation.html#installing-the-recommended-dependencies

# %% [markdown]
# ## 구성
# 1. 데이터 불러오기
# 2. 데이터 체크(형태, 구조, 자료형 확인)
# 3. 데이터 전처리
#     - minmax
#     - resize 등
# 4. 2번 다시
# 5. 시각화

# %%
### HYPER PARAMETER ###

RANDOM_SEED = 831
IMAGE_SIZE = (128, 128, 128)
BATCH_SIZE = 2
NUM_CLASS = 2
EPOCHS = 100
test_ratio, val_ratio = 0.1, 0.2

MODEL_SAVE = False
if MODEL_SAVE:
    model_dir1 = '/data/MODEL_BG/'
    model_dir2 = 'Segmentation(3D)-UNet(monai)'
    MODEL_SAVE_PATH = os.path.join(model_dir1, model_dir2)
    os.makedirs(MODEL_SAVE_PATH, exist_ok=True)
    
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# DEVICE = 'cpu'

# %% [markdown]
# 0. 데이터 준비
# - 데이터가 있으면 `data_dir`를 자신의 경로에 맞게 수정해주세요.
# - 데이터가 없으면 `USE_MY_DATA` 를 `False`로 두고 다운로드 받으면 됩니다.
# - The dataset comes from http://medicaldecathlon.com/.

# %%
USE_MY_DATA = True

if not USE_MY_DATA:
    directory = os.environ.get("MONAI_DATA_DIRECTORY")
    root_dir = tempfile.mkdtemp() if directory is None else directory
    print(f"root dir is: {root_dir}")
    
    resource = "https://msd-for-monai.s3-us-west-2.amazonaws.com/Task09_Spleen.tar"
    md5 = "410d4a301da4e5b2f6f86ec3ddba524e"

    compressed_file = os.path.join(root_dir, "Task09_Spleen.tar")
    data_dir = os.path.join(root_dir, "Task09_Spleen")
    if not os.path.exists(data_dir):
        download_and_extract(resource, compressed_file, root_dir, md5)

else:
    data_dir = '/data/MSD/Task09_Spleen'

# %%
train_images = sorted(
    glob.glob(os.path.join(data_dir, "imagesTr", "*.nii.gz")))
train_labels = sorted(
    glob.glob(os.path.join(data_dir, "labelsTr", "*.nii.gz")))
data_dicts = [
    {"image": image_name, "label": label_name}
    for image_name, label_name in zip(train_images, train_labels)
]
train_data_dicts, val_data_dicts = data_dicts[:-9], data_dicts[-9:]
train_data_dicts[0]
# Out:
# {'image': '/data/MSD/Task09_Spleen/imagesTr/spleen_10.nii.gz',
#  'label': '/data/MSD/Task09_Spleen/labelsTr/spleen_10.nii.gz'}

# %% [markdown]
# 1. 데이터 불러오기

# %%
train_images = sorted(
    glob.glob(os.path.join(data_dir, "imagesTr", "*.nii.gz")))
train_labels = sorted(
    glob.glob(os.path.join(data_dir, "labelsTr", "*.nii.gz")))

data_dicts = [
    {"image": image_name, "label": label_name}
    for image_name, label_name in zip(train_images, train_labels)
]

TrainSet, TestSet = model_selection.train_test_split(data_dicts, test_size=test_ratio, random_state=RANDOM_SEED)
TrainSet, ValSet = model_selection.train_test_split(TrainSet, test_size=val_ratio, random_state=RANDOM_SEED)
print('TrainSet:', len(TrainSet), 'ValSet:', len(ValSet), 'TestSet:', len(TestSet))
# Out:
# img cnt: 41 ['/data/MSD/Task09_Spleen/imagesTr/spleen_10.nii.gz']
# mask cn:; 41 ['/data/MSD/Task09_Spleen/labelsTr/spleen_10.nii.gz']
# TrainSet: 28 ValSet: 8 TestSet: 5

# %% [markdown]
# 2. 데이터 체크(형태, 구조, 자료형 확인)

# %%
for i in range(3):
    sample_img = nib.load(TrainSet[i]['image']).get_fdata()
    sample_mask = nib.load(TrainSet[i]['label']).get_fdata()
    print(f"[sample {i+1}] {os.path.basename(TrainSet[i]['image'])} {os.path.basename(TrainSet[i]['label'])}")
    print(sample_img.shape, sample_img.dtype, np.min(sample_img), np.max(sample_img))
    print(sample_mask.shape, sample_mask.dtype, np.unique(sample_mask))
# Out:
# [sample 1] spleen_2.nii.gz spleen_2.nii.gz
# (512, 512, 90) float64 -1024.0 3071.0
# (512, 512, 90) float64 [0. 1.]
# [sample 2] spleen_19.nii.gz spleen_19.nii.gz
# (512, 512, 51) float64 -1024.0 1372.0
# (512, 512, 51) float64 [0. 1.]
# [sample 3] spleen_17.nii.gz spleen_17.nii.gz
# (512, 512, 95) float64 -1024.0 1964.0
# (512, 512, 95) float64 [0. 1.]

# %% [markdown]
# 3. 데이터 전처리
#     - minmax
#     - resize 등

# %%
from monai.transforms.compose import Transform, MapTransform

class MinMax(MapTransform):
    def __init__(self, keys):
        super().__init__(keys)

    def __call__(self, data):
        d = dict(data)
        for key in self.keys:
            d[key] -= np.min(d[key])
            d[key] /= np.max(d[key])
        return d

loader = LoadImaged(keys=("image",'label'), image_only=False)
ensure_channel_first = EnsureChannelFirstd(keys=["image",'label'])
orientation = Orientationd(keys=["image",'label'], axcodes="RAS")
resize_img = Resized(keys=["image",], spatial_size=(IMAGE_SIZE), mode='trilinear')
resize_mask = Resized(keys=['label',], spatial_size=(IMAGE_SIZE), mode='nearest-exact')
# normalize = NormalizeIntensityd(keys=["image",])
minmax = MinMax(keys=['image',])

# %% [markdown]
# 2. 데이터 체크(형태, 구조, 자료형 확인)

# %%
transforms = Compose([
    LoadImaged(keys=("image",'label'), image_only=False),
    EnsureChannelFirstd(keys=["image",'label']),
    Orientationd(keys=["image",'label'], axcodes="RAS"),
    Resized(keys=["image",], spatial_size=(IMAGE_SIZE), mode='trilinear'),
    Resized(keys=['label',], spatial_size=(IMAGE_SIZE), mode='nearest-exact'),
    # normalize = NormalizeIntensityd(keys=["image",])
    MinMax(keys=['image',]),
    ToTensord(keys=["image", "label"]),
    ])

SampleSet = transforms(TestSet[:3])

for i in range(3):
    sample_img = SampleSet[i]['image']
    sample_mask = SampleSet[i]['label']
    print(f"[sample {i+1}]")
    print(sample_img.shape, sample_img.dtype, torch.min(sample_img), torch.max(sample_img))
    print(sample_mask.shape, sample_mask.dtype, torch.unique(sample_mask))
# Out:
# [sample 1]
# (1, 128, 128, 128) torch.float32 tensor(0.) tensor(1.)
# (1, 128, 128, 128) torch.float32 tensor([0., 1.])
# [sample 2]
# (1, 128, 128, 128) torch.float32 tensor(0.) tensor(1.)
# (1, 128, 128, 128) torch.float32 tensor([0., 1.])
# [sample 3]
# (1, 128, 128, 128) torch.float32 tensor(0.) tensor(1.)
# (1, 128, 128, 128) torch.float32 tensor([0., 1.])

# %% [markdown]
# 5. 시각화

# %%
ncols, nrows = 10, 6
interval = int(IMAGE_SIZE[-1]//(ncols*nrows/2))
fig, axes = plt.subplots(ncols=ncols, nrows=nrows, figsize=(ncols,nrows))
cnt1, cnt2 = 0, 0
for i in range(nrows):
    for j in range(ncols):
        if i%2 == 0:
            axes[i,j].imshow(SampleSet[0]['image'][0,:,:,cnt1], cmap='gray')
            cnt1+=interval
        else:
            axes[i,j].imshow(SampleSet[0]['label'][0,:,:,cnt2], cmap='gray')
            cnt2+=interval
        axes[i,j].axis('off')
plt.subplots_adjust(wspace=0, hspace=0, left=0, right=1, bottom=0, top=1)
plt.show()

# %% [markdown]
# 6. Data pipeline build

# %%
from monai.data import (
    DataLoader,
    CacheDataset,
    load_decathlon_datalist,
    decollate_batch,
)

train_ds = CacheDataset(
    data=TrainSet,
    transform=transforms,
    cache_num=4,
    cache_rate=1.0,
    num_workers=0)
val_ds = CacheDataset(
    data=ValSet, transform=transforms, cache_num=2, cache_rate=1.0, num_workers=0)
test_ds = CacheDataset(
    data=TestSet, transform=transforms, cache_num=2, cache_rate=1.0, num_workers=0)

train_loader = DataLoader(
    train_ds, batch_size=BATCH_SIZE, shuffle=True, num_workers=0, pin_memory=True)
val_loader = DataLoader(
    val_ds, batch_size=1, shuffle=False, num_workers=0, pin_memory=True)
test_loader = DataLoader(
    test_ds, batch_size=1, shuffle=False, num_workers=0, pin_memory=True)
# Out:
# Loading dataset: 100%|███████████████████████████████████████████████████████| 4/4 [00:02<00:00,  1.81it/s]
# Loading dataset: 100%|███████████████████████████████████████████████████████| 2/2 [00:00<00:00,  2.42it/s]
# Loading dataset: 100%|███████████████████████████████████████████████████████| 2/2 [00:02<00:00,  1.08s/it]

# %% [markdown]
# 7. model build

# %%
model = UNet(
    spatial_dims=3,
    in_channels=1,
    out_channels=NUM_CLASS,
    channels=(16, 32, 64, 128, 256),
    strides=(2, 2, 2, 2),
    num_res_units=2,
    norm=Norm.BATCH,
).float()
model = model.to(DEVICE)
model_summary(model, (1,*IMAGE_SIZE), device=DEVICE.type)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv3d-1       [-1, 16, 64, 64, 64]             448
#             Conv3d-2       [-1, 16, 64, 64, 64]             448
#        BatchNorm3d-3       [-1, 16, 64, 64, 64]              32
#            Dropout-4       [-1, 16, 64, 64, 64]               0
#              PReLU-5       [-1, 16, 64, 64, 64]               1
#             Conv3d-6       [-1, 16, 64, 64, 64]           6,928
#        BatchNorm3d-7       [-1, 16, 64, 64, 64]              32
#            Dropout-8       [-1, 16, 64, 64, 64]               0
#              PReLU-9       [-1, 16, 64, 64, 64]               1
#      ResidualUnit-10       [-1, 16, 64, 64, 64]               0
#            Conv3d-11       [-1, 32, 32, 32, 32]          13,856
#            Conv3d-12       [-1, 32, 32, 32, 32]          13,856
#       BatchNorm3d-13       [-1, 32, 32, 32, 32]              64
#           Dropout-14       [-1, 32, 32, 32, 32]               0
#             PReLU-15       [-1, 32, 32, 32, 32]               1
#            Conv3d-16       [-1, 32, 32, 32, 32]          27,680
#       BatchNorm3d-17       [-1, 32, 32, 32, 32]              64
#           Dropout-18       [-1, 32, 32, 32, 32]               0
#             PReLU-19       [-1, 32, 32, 32, 32]               1
#      ResidualUnit-20       [-1, 32, 32, 32, 32]               0
#            Conv3d-21       [-1, 64, 16, 16, 16]          55,360
#            Conv3d-22       [-1, 64, 16, 16, 16]          55,360
#       BatchNorm3d-23       [-1, 64, 16, 16, 16]             128
#           Dropout-24       [-1, 64, 16, 16, 16]               0
#             PReLU-25       [-1, 64, 16, 16, 16]               1
#            Conv3d-26       [-1, 64, 16, 16, 16]         110,656
#       BatchNorm3d-27       [-1, 64, 16, 16, 16]             128
#           Dropout-28       [-1, 64, 16, 16, 16]               0
#             PReLU-29       [-1, 64, 16, 16, 16]               1
#      ResidualUnit-30       [-1, 64, 16, 16, 16]               0
#            Conv3d-31         [-1, 128, 8, 8, 8]         221,312
#            Conv3d-32         [-1, 128, 8, 8, 8]         221,312
#       BatchNorm3d-33         [-1, 128, 8, 8, 8]             256
#           Dropout-34         [-1, 128, 8, 8, 8]               0
#             PReLU-35         [-1, 128, 8, 8, 8]               1
#            Conv3d-36         [-1, 128, 8, 8, 8]         442,496
#       BatchNorm3d-37         [-1, 128, 8, 8, 8]             256
#           Dropout-38         [-1, 128, 8, 8, 8]               0
#             PReLU-39         [-1, 128, 8, 8, 8]               1
#      ResidualUnit-40         [-1, 128, 8, 8, 8]               0
#            Conv3d-41         [-1, 256, 8, 8, 8]          33,024
#            Conv3d-42         [-1, 256, 8, 8, 8]         884,992
#       BatchNorm3d-43         [-1, 256, 8, 8, 8]             512
#           Dropout-44         [-1, 256, 8, 8, 8]               0
#             PReLU-45         [-1, 256, 8, 8, 8]               1
#            Conv3d-46         [-1, 256, 8, 8, 8]       1,769,728
#       BatchNorm3d-47         [-1, 256, 8, 8, 8]             512
#           Dropout-48         [-1, 256, 8, 8, 8]               0
#             PReLU-49         [-1, 256, 8, 8, 8]               1
#      ResidualUnit-50         [-1, 256, 8, 8, 8]               0
#    SkipConnection-51         [-1, 384, 8, 8, 8]               0
#   ConvTranspose3d-52       [-1, 64, 16, 16, 16]         663,616
#       BatchNorm3d-53       [-1, 64, 16, 16, 16]             128
#           Dropout-54       [-1, 64, 16, 16, 16]               0
#             PReLU-55       [-1, 64, 16, 16, 16]               1
#          Identity-56       [-1, 64, 16, 16, 16]               0
#            Conv3d-57       [-1, 64, 16, 16, 16]         110,656
#       BatchNorm3d-58       [-1, 64, 16, 16, 16]             128
#           Dropout-59       [-1, 64, 16, 16, 16]               0
#             PReLU-60       [-1, 64, 16, 16, 16]               1
#      ResidualUnit-61       [-1, 64, 16, 16, 16]               0
#    SkipConnection-62      [-1, 128, 16, 16, 16]               0
#   ConvTranspose3d-63       [-1, 32, 32, 32, 32]         110,624
#       BatchNorm3d-64       [-1, 32, 32, 32, 32]              64
#           Dropout-65       [-1, 32, 32, 32, 32]               0
#             PReLU-66       [-1, 32, 32, 32, 32]               1
#          Identity-67       [-1, 32, 32, 32, 32]               0
#            Conv3d-68       [-1, 32, 32, 32, 32]          27,680
#       BatchNorm3d-69       [-1, 32, 32, 32, 32]              64
#           Dropout-70       [-1, 32, 32, 32, 32]               0
#             PReLU-71       [-1, 32, 32, 32, 32]               1
#      ResidualUnit-72       [-1, 32, 32, 32, 32]               0
#    SkipConnection-73       [-1, 64, 32, 32, 32]               0
#   ConvTranspose3d-74       [-1, 16, 64, 64, 64]          27,664
#       BatchNorm3d-75       [-1, 16, 64, 64, 64]              32
#           Dropout-76       [-1, 16, 64, 64, 64]               0
#             PReLU-77       [-1, 16, 64, 64, 64]               1
#          Identity-78       [-1, 16, 64, 64, 64]               0
#            Conv3d-79       [-1, 16, 64, 64, 64]           6,928
#       BatchNorm3d-80       [-1, 16, 64, 64, 64]              32
#           Dropout-81       [-1, 16, 64, 64, 64]               0
#             PReLU-82       [-1, 16, 64, 64, 64]               1
#      ResidualUnit-83       [-1, 16, 64, 64, 64]               0
#    SkipConnection-84       [-1, 32, 64, 64, 64]               0
#   ConvTranspose3d-85     [-1, 2, 128, 128, 128]           1,730
#       BatchNorm3d-86     [-1, 2, 128, 128, 128]               4
#           Dropout-87     [-1, 2, 128, 128, 128]               0
#             PReLU-88     [-1, 2, 128, 128, 128]               1
#          Identity-89     [-1, 2, 128, 128, 128]               0
#            Conv3d-90     [-1, 2, 128, 128, 128]             110
#      ResidualUnit-91     [-1, 2, 128, 128, 128]               0
# ================================================================
# Total params: 4,808,917
# Trainable params: 4,808,917
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 8.00
# Forward/backward pass size (MB): 1164.50
# Params size (MB): 18.34
# Estimated Total Size (MB): 1190.84
# ----------------------------------------------------------------

# %% [markdown]
# 8. optimizer, loss, metric 등 구성

# %%
from monai.losses import DiceCELoss, DiceLoss

torch.backends.cudnn.benchmark = True # ??

optimizer = torch.optim.Adam(model.parameters(), lr=1e-4, weight_decay=1e-4)
# scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=50, gamma=0.1)

LossFuncion = monai.losses.DiceLoss(include_background=False, to_onehot_y=False, softmax=True)
MetricDice = monai.metrics.DiceMetric(include_background=False, reduction="mean")

# %%
def BinaryOutput(output, keepdim=True):
    shape = output.shape
    argmax_idx = torch.argmax(output, axis=1, keepdim=True)
    argmax_oh = F.one_hot(argmax_idx, num_classes=NUM_CLASS)
    if keepdim:
        argmax_oh = torch.squeeze(argmax_oh, dim=1)
    if len(shape) == 5:
        argmax_oh = argmax_oh.permute(0,4,1,2,3)
    elif len(shape) == 4:
        argmax_oh = argmax_oh.permute(0,3,1,2)
    
    return argmax_oh

# %% [markdown]
# 9. train & evalute loop

# %%
from monai.losses.dice import DiceLoss, one_hot

def train(epoch, train_loader):
    model.train()
    mean_epoch_loss = 0
    mean_dice_score = 0
    epoch_iterator = tqdm(
        train_loader, desc="Training (X / X EPOCHS) (loss=X.X) (dice score=%.5f)", 
        dynamic_ncols=True)
    
    for step, batch in enumerate(epoch_iterator):
        x, y = (batch["image"].cuda(), batch["label"].cuda())
        y = torch.squeeze(y, dim=1)
        y = one_hot(y[:, None, ...], num_classes=NUM_CLASS)
        
        logit_map = model(x)
        loss = LossFuncion(logit_map, y)
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()
        mean_epoch_loss += loss.item()
        
        bi_output = BinaryOutput(logit_map)
        MetricDice(bi_output, y)
        dice_score = MetricDice.aggregate().item()
        mean_dice_score += dice_score
        
        epoch_iterator.set_description(
            "Training (%d / %d EPOCHS) (loss=%2.5f) (dice score=%.5f)" 
            % (epoch, EPOCHS, loss, dice_score))
    
    mean_epoch_loss /= len(epoch_iterator)
    mean_dice_score /= len(epoch_iterator)
    
    return mean_epoch_loss, mean_dice_score



def evaluate(epoch, test_loader):
    model.eval() 
    mean_epoch_loss = 0
    mean_dice_score = 0
    epoch_iterator = tqdm(
        test_loader, desc="Evaluating (X / X EPOCHS) (loss=X.X) (dice score=%.5f)", 
        dynamic_ncols=True)
    
    with torch.no_grad():
        for step, batch in enumerate(epoch_iterator):
            x, y = (batch["image"].cuda(), batch["label"].cuda())
            y = torch.squeeze(y, dim=1)
            y = one_hot(y[:, None, ...], num_classes=NUM_CLASS)

            logit_map = model(x)
            loss = LossFuncion(logit_map, y)
            mean_epoch_loss += loss.item()

            bi_output = BinaryOutput(logit_map)
            MetricDice(bi_output, y)
            dice_score = MetricDice.aggregate().item()
            mean_dice_score += dice_score

            epoch_iterator.set_description(
                "Evaluating (%d / %d EPOCHS) (loss=%2.5f) (dice score=%.5f)" 
                % (epoch, EPOCHS, loss, dice_score))

    mean_epoch_loss /= len(epoch_iterator)
    mean_dice_score /= len(epoch_iterator)
    
    MetricDice.reset() # reset the status for next validation round
    
    return mean_epoch_loss, mean_dice_score

# %% [markdown]
# 10. let's training

# %%
losses = {'train':[], 'val':[]}
dice_scores = {'train':[], 'val':[]}
best_metric, best_epoch = 999, -1

for epoch in range(1, EPOCHS+1):
    train_loss, train_dice_score = train(epoch, train_loader)
    val_loss, val_dice_score = evaluate(epoch, val_loader)
    
    losses['train'].append(train_loss)
    losses['val'].append(val_loss)
    dice_scores['train'].append(train_dice_score)
    dice_scores['val'].append(val_dice_score)

    if losses['val'][-1] < best_metric:
        best_metric = losses['val'][-1]
        best_epoch = epoch
        print(f'Best record! [{epoch}] Test Loss: {val_loss:.6f}, Dice score: {val_dice_score:.6f}')
        if MODEL_SAVE:
            model_name = f'{best_epoch}_{best_metric}.pth'
            torch.save(model.state_dict(), os.path.join(MODEL_SAVE_PATH, model_name))
            print('saved model')
# Out:
# Training (1 / 100 EPOCHS) (loss=0.98408) (dice score=0.01211): 100%|███████| 14/14 [00:16<00:00,  1.19s/it]
# Evaluating (1 / 100 EPOCHS) (loss=0.99053) (dice score=0.01227): 100%|███████| 8/8 [00:03<00:00,  2.46it/s]
# Best record! [1] Test Loss: 0.987869, Dice score: 0.012067
# saved model
# Training (2 / 100 EPOCHS) (loss=0.98855) (dice score=0.01660): 100%|███████| 14/14 [00:15<00:00,  1.14s/it]
# Evaluating (2 / 100 EPOCHS) (loss=0.98501) (dice score=0.01720): 100%|███████| 8/8 [00:03<00:00,  2.62it/s]
# Best record! [2] Test Loss: 0.982449, Dice score: 0.016744
# saved model
# Training (3 / 100 EPOCHS) (loss=0.98580) (dice score=0.01924): 100%|███████| 14/14 [00:15<00:00,  1.14s/it]
# Evaluating (3 / 100 EPOCHS) (loss=0.98370) (dice score=0.01955): 100%|███████| 8/8 [00:03<00:00,  2.61it/s]
# Best record! [3] Test Loss: 0.980531, Dice score: 0.019175
# saved model
# Training (4 / 100 EPOCHS) (loss=0.96863) (dice score=0.02172): 100%|███████| 14/14 [00:15<00:00,  1.14s/it]
# Evaluating (4 / 100 EPOCHS) (loss=0.98227) (dice score=0.02261): 100%|███████| 8/8 [00:03<00:00,  2.62it/s]
# Best record! [4] Test Loss: 0.978542, Dice score: 0.021987
# saved model
# Training (5 / 100 EPOCHS) (loss=0.97918) (dice score=0.02416): 100%|███████| 14/14 [00:15<00:00,  1.14s/it]
# Evaluating (5 / 100 EPOCHS) (loss=0.98166) (dice score=0.02474): 100%|███████| 8/8 [00:03<00:00,  2.61it/s]
# Best record! [5] Test Loss: 0.977369, Dice score: 0.024197
# saved model
# Training (6 / 100 EPOCHS) (loss=0.96375) (dice score=0.02588): 100%|███████| 14/14 [00:16<00:00,  1.14s/it]
# Evaluating (6 / 100 EPOCHS) (loss=0.98055) (dice score=0.02649): 100%|███████| 8/8 [00:03<00:00,  2.62it/s]
# Training (7 / 100 EPOCHS) (loss=0.98175) (dice score=0.02665): 100%|███████| 14/14 [00:16<00:00,  1.15s/it]
# Evaluating (7 / 100 EPOCHS) (loss=0.97988) (dice score=0.02757): 100%|███████| 8/8 [00:03<00:00,  2.63it/s]
# Best record! [7] Test Loss: 0.976089, Dice score: 0.026856
# saved model
# Training (8 / 100 EPOCHS) (loss=0.98838) (dice score=0.02806): 100%|███████| 14/14 [00:16<00:00,  1.15s/it]
# Evaluating (8 / 100 EPOCHS) (loss=0.97904) (dice score=0.02959): 100%|███████| 8/8 [00:03<00:00,  2.57it/s]
# Best record! [8] Test Loss: 0.974755, Dice score: 0.028624
# saved model
# Training (9 / 100 EPOCHS) (loss=0.98504) (dice score=0.03195): 100%|███████| 14/14 [00:16<00:00,  1.15s/it]
# Evaluating (9 / 100 EPOCHS) (loss=0.97825) (dice score=0.03319): 100%|███████| 8/8 [00:03<00:00,  2.60it/s]
# Training (10 / 100 EPOCHS) (loss=0.97310) (dice score=0.03576): 100%|██████| 14/14 [00:16<00:00,  1.15s/it]
# Evaluating (10 / 100 EPOCHS) (loss=0.97768) (dice score=0.03674): 100%|██████| 8/8 [00:03<00:00,  2.57it/s]
# Best record! [10] Test Loss: 0.974243, Dice score: 0.035821
# saved model
# Training (11 / 100 EPOCHS) (loss=0.97212) (dice score=0.03816): 100%|██████| 14/14 [00:16<00:00,  1.14s/it]
# Evaluating (11 / 100 EPOCHS) (loss=0.97712) (dice score=0.03913): 100%|██████| 8/8 [00:03<00:00,  2.60it/s]
# Training (12 / 100 EPOCHS) (loss=0.98376) (dice score=0.04160): 100%|██████| 14/14 [00:16<00:00,  1.14s/it]
# Evaluating (12 / 100 EPOCHS) (loss=0.97772) (dice score=0.04278): 100%|██████| 8/8 [00:03<00:00,  2.59it/s]
# Best record! [12] Test Loss: 0.972425, Dice score: 0.041826
# saved model
# Training (13 / 100 EPOCHS) (loss=0.96028) (dice score=0.04646): 100%|██████| 14/14 [00:16<00:00,  1.15s/it]
# Evaluating (13 / 100 EPOCHS) (loss=0.97872) (dice score=0.04402): 100%|██████| 8/8 [00:03<00:00,  2.61it/s]
# Training (14 / 100 EPOCHS) (loss=0.97182) (dice score=0.05029): 100%|██████| 14/14 [00:16<00:00,  1.15s/it]
# Evaluating (14 / 100 EPOCHS) (loss=0.97761) (dice score=0.04936): 100%|██████| 8/8 [00:03<00:00,  2.58it/s]
# Best record! [14] Test Loss: 0.971970, Dice score: 0.049171
# saved model
# Training (15 / 100 EPOCHS) (loss=0.98368) (dice score=0.05450): 100%|██████| 14/14 [00:16<00:00,  1.15s/it]
# Evaluating (15 / 100 EPOCHS) (loss=0.97425) (dice score=0.05718): 100%|██████| 8/8 [00:03<00:00,  2.61it/s]
# Training (16 / 100 EPOCHS) (loss=0.98514) (dice score=0.06710): 100%|██████| 14/14 [00:16<00:00,  1.15s/it]
# Evaluating (16 / 100 EPOCHS) (loss=0.97403) (dice score=0.06759): 100%|██████| 8/8 [00:03<00:00,  2.61it/s]
# Best record! [16] Test Loss: 0.971115, Dice score: 0.066820
# saved model
# Training (17 / 100 EPOCHS) (loss=0.97939) (dice score=0.07252): 100%|██████| 14/14 [00:16<00:00,  1.14s/it]
# Evaluating (17 / 100 EPOCHS) (loss=0.97323) (dice score=0.07469): 100%|██████| 8/8 [00:03<00:00,  2.62it/s]
# Best record! [17] Test Loss: 0.969117, Dice score: 0.072737
# saved model
# Training (18 / 100 EPOCHS) (loss=0.95841) (dice score=0.08888): 100%|██████| 14/14 [00:15<00:00,  1.14s/it]
# Evaluating (18 / 100 EPOCHS) (loss=0.97132) (dice score=0.09031): 100%|██████| 8/8 [00:03<00:00,  2.62it/s]
# Best record! [18] Test Loss: 0.968301, Dice score: 0.088110
# saved model
# Training (19 / 100 EPOCHS) (loss=0.97818) (dice score=0.12356): 100%|██████| 14/14 [00:15<00:00,  1.14s/it]
# Evaluating (19 / 100 EPOCHS) (loss=0.96994) (dice score=0.14251): 100%|██████| 8/8 [00:03<00:00,  2.59it/s]
# Best record! [19] Test Loss: 0.965397, Dice score: 0.134432
# saved model
# Training (20 / 100 EPOCHS) (loss=0.96352) (dice score=0.14691): 100%|██████| 14/14 [00:16<00:00,  1.14s/it]
# Evaluating (20 / 100 EPOCHS) (loss=0.97056) (dice score=0.15485): 100%|██████| 8/8 [00:03<00:00,  2.62it/s]
# Best record! [20] Test Loss: 0.964077, Dice score: 0.150037
# saved model
# Training (21 / 100 EPOCHS) (loss=0.98293) (dice score=0.20100): 100%|██████| 14/14 [00:15<00:00,  1.14s/it]
# Evaluating (21 / 100 EPOCHS) (loss=0.96943) (dice score=0.19982): 100%|██████| 8/8 [00:03<00:00,  2.62it/s]
# Training (22 / 100 EPOCHS) (loss=0.95967) (dice score=0.22878): 100%|██████| 14/14 [00:15<00:00,  1.14s/it]
# Evaluating (22 / 100 EPOCHS) (loss=0.96782) (dice score=0.23346): 100%|██████| 8/8 [00:03<00:00,  2.62it/s]
# Training (23 / 100 EPOCHS) (loss=0.97746) (dice score=0.24061): 100%|██████| 14/14 [00:16<00:00,  1.15s/it]
# Evaluating (23 / 100 EPOCHS) (loss=0.96571) (dice score=0.26096): 100%|██████| 8/8 [00:03<00:00,  2.57it/s]
# Training (24 / 100 EPOCHS) (loss=0.97519) (dice score=0.20913): 100%|██████| 14/14 [00:16<00:00,  1.15s/it]
# Evaluating (24 / 100 EPOCHS) (loss=0.96553) (dice score=0.20787): 100%|██████| 8/8 [00:03<00:00,  2.60it/s]
# Best record! [24] Test Loss: 0.957843, Dice score: 0.207056
# saved model
# Training (25 / 100 EPOCHS) (loss=0.97438) (dice score=0.23753): 100%|██████| 14/14 [00:15<00:00,  1.14s/it]
# Evaluating (25 / 100 EPOCHS) (loss=0.96235) (dice score=0.24149): 100%|██████| 8/8 [00:03<00:00,  2.62it/s]
# Training (26 / 100 EPOCHS) (loss=0.95282) (dice score=0.28096): 100%|██████| 14/14 [00:15<00:00,  1.14s/it]
# Evaluating (26 / 100 EPOCHS) (loss=0.96061) (dice score=0.28510): 100%|██████| 8/8 [00:03<00:00,  2.62it/s]
# Best record! [26] Test Loss: 0.957037, Dice score: 0.280405
# saved model
# Training (27 / 100 EPOCHS) (loss=0.92953) (dice score=0.24224): 100%|██████| 14/14 [00:16<00:00,  1.15s/it]
# Evaluating (27 / 100 EPOCHS) (loss=0.96443) (dice score=0.22149): 100%|██████| 8/8 [00:03<00:00,  2.61it/s]
# Best record! [27] Test Loss: 0.956082, Dice score: 0.228006
# saved model
# Training (28 / 100 EPOCHS) (loss=0.96352) (dice score=0.23618): 100%|██████| 14/14 [00:16<00:00,  1.15s/it]
# Evaluating (28 / 100 EPOCHS) (loss=0.95880) (dice score=0.23505): 100%|██████| 8/8 [00:03<00:00,  2.61it/s]
# Best record! [28] Test Loss: 0.954370, Dice score: 0.233311
# saved model
# Training (29 / 100 EPOCHS) (loss=0.94507) (dice score=0.23389): 100%|██████| 14/14 [00:16<00:00,  1.14s/it]
# Evaluating (29 / 100 EPOCHS) (loss=0.95676) (dice score=0.22290): 100%|██████| 8/8 [00:03<00:00,  2.60it/s]
# Best record! [29] Test Loss: 0.954265, Dice score: 0.223886
# saved model
# Training (30 / 100 EPOCHS) (loss=0.94807) (dice score=0.26284): 100%|██████| 14/14 [00:15<00:00,  1.14s/it]
# Evaluating (30 / 100 EPOCHS) (loss=0.96005) (dice score=0.24341): 100%|██████| 8/8 [00:03<00:00,  2.60it/s]
# Best record! [30] Test Loss: 0.951016, Dice score: 0.249112
# saved model
# Training (31 / 100 EPOCHS) (loss=0.97482) (dice score=0.21071): 100%|██████| 14/14 [00:16<00:00,  1.15s/it]
# Evaluating (31 / 100 EPOCHS) (loss=0.95080) (dice score=0.23946): 100%|██████| 8/8 [00:03<00:00,  2.62it/s]
# Best record! [31] Test Loss: 0.942765, Dice score: 0.229165
# saved model
# Training (32 / 100 EPOCHS) (loss=0.93201) (dice score=0.28480): 100%|██████| 14/14 [00:16<00:00,  1.16s/it]
# Evaluating (32 / 100 EPOCHS) (loss=0.95075) (dice score=0.29524): 100%|██████| 8/8 [00:03<00:00,  2.55it/s]
# Training (33 / 100 EPOCHS) (loss=0.96735) (dice score=0.28234): 100%|██████| 14/14 [00:16<00:00,  1.17s/it]
# Evaluating (33 / 100 EPOCHS) (loss=0.95143) (dice score=0.26639): 100%|██████| 8/8 [00:03<00:00,  2.56it/s]
# Training (34 / 100 EPOCHS) (loss=0.96346) (dice score=0.25768): 100%|██████| 14/14 [00:16<00:00,  1.16s/it]
# Evaluating (34 / 100 EPOCHS) (loss=0.93695) (dice score=0.26592): 100%|██████| 8/8 [00:03<00:00,  2.55it/s]
# Best record! [34] Test Loss: 0.928881, Dice score: 0.260992
# saved model
# Training (35 / 100 EPOCHS) (loss=0.92569) (dice score=0.30582): 100%|██████| 14/14 [00:16<00:00,  1.16s/it]
# Evaluating (35 / 100 EPOCHS) (loss=0.94129) (dice score=0.29825): 100%|██████| 8/8 [00:03<00:00,  2.60it/s]
# Training (36 / 100 EPOCHS) (loss=0.94958) (dice score=0.34008): 100%|██████| 14/14 [00:16<00:00,  1.16s/it]
# Evaluating (36 / 100 EPOCHS) (loss=0.93398) (dice score=0.34107): 100%|██████| 8/8 [00:03<00:00,  2.57it/s]
# Training (37 / 100 EPOCHS) (loss=0.90861) (dice score=0.34665): 100%|██████| 14/14 [00:16<00:00,  1.16s/it]
# Evaluating (37 / 100 EPOCHS) (loss=0.93305) (dice score=0.33578): 100%|██████| 8/8 [00:03<00:00,  2.56it/s]
# Best record! [37] Test Loss: 0.923838, Dice score: 0.339477
# saved model
# Training (38 / 100 EPOCHS) (loss=0.90604) (dice score=0.31942): 100%|██████| 14/14 [00:16<00:00,  1.16s/it]
# Evaluating (38 / 100 EPOCHS) (loss=0.91853) (dice score=0.30996): 100%|██████| 8/8 [00:03<00:00,  2.58it/s]
# Best record! [38] Test Loss: 0.902613, Dice score: 0.312303
# saved model
# Training (39 / 100 EPOCHS) (loss=0.90166) (dice score=0.30996): 100%|██████| 14/14 [00:16<00:00,  1.16s/it]
# Evaluating (39 / 100 EPOCHS) (loss=0.93231) (dice score=0.29942): 100%|██████| 8/8 [00:03<00:00,  2.58it/s]
# Training (40 / 100 EPOCHS) (loss=0.94916) (dice score=0.32605): 100%|██████| 14/14 [00:16<00:00,  1.16s/it]
# Evaluating (40 / 100 EPOCHS) (loss=0.91767) (dice score=0.32720): 100%|██████| 8/8 [00:03<00:00,  2.59it/s]
# Training (41 / 100 EPOCHS) (loss=0.90082) (dice score=0.35282): 100%|██████| 14/14 [00:16<00:00,  1.16s/it]
# Evaluating (41 / 100 EPOCHS) (loss=0.91341) (dice score=0.35272): 100%|██████| 8/8 [00:03<00:00,  2.56it/s]
# Training (42 / 100 EPOCHS) (loss=0.90663) (dice score=0.38565): 100%|██████| 14/14 [00:16<00:00,  1.16s/it]
# Evaluating (42 / 100 EPOCHS) (loss=0.89546) (dice score=0.38424): 100%|██████| 8/8 [00:03<00:00,  2.59it/s]
# Best record! [42] Test Loss: 0.901902, Dice score: 0.380944
# saved model
# Training (43 / 100 EPOCHS) (loss=0.82783) (dice score=0.39865): 100%|██████| 14/14 [00:16<00:00,  1.15s/it]
# Evaluating (43 / 100 EPOCHS) (loss=0.87008) (dice score=0.39218): 100%|██████| 8/8 [00:03<00:00,  2.60it/s]
# Best record! [43] Test Loss: 0.888303, Dice score: 0.391067
# saved model
# Training (44 / 100 EPOCHS) (loss=0.90631) (dice score=0.38745): 100%|██████| 14/14 [00:16<00:00,  1.16s/it]
# Evaluating (44 / 100 EPOCHS) (loss=0.90278) (dice score=0.37985): 100%|██████| 8/8 [00:03<00:00,  2.58it/s]
# Training (45 / 100 EPOCHS) (loss=0.90433) (dice score=0.39335): 100%|██████| 14/14 [00:16<00:00,  1.15s/it]
# Evaluating (45 / 100 EPOCHS) (loss=0.79614) (dice score=0.38622): 100%|██████| 8/8 [00:03<00:00,  2.60it/s]
# Best record! [45] Test Loss: 0.853361, Dice score: 0.384951
# saved model
# Training (46 / 100 EPOCHS) (loss=0.88336) (dice score=0.37475): 100%|██████| 14/14 [00:16<00:00,  1.16s/it]
# Evaluating (46 / 100 EPOCHS) (loss=0.95276) (dice score=0.33748): 100%|██████| 8/8 [00:03<00:00,  2.57it/s]
# Training (47 / 100 EPOCHS) (loss=0.71355) (dice score=0.28465): 100%|██████| 14/14 [00:16<00:00,  1.16s/it]
# Evaluating (47 / 100 EPOCHS) (loss=0.97632) (dice score=0.24324): 100%|██████| 8/8 [00:03<00:00,  2.60it/s]
# Training (48 / 100 EPOCHS) (loss=0.81844) (dice score=0.18769): 100%|██████| 14/14 [00:16<00:00,  1.19s/it]
# Evaluating (48 / 100 EPOCHS) (loss=0.78869) (dice score=0.18138): 100%|██████| 8/8 [00:03<00:00,  2.59it/s]
# Training (49 / 100 EPOCHS) (loss=0.95606) (dice score=0.19647): 100%|██████| 14/14 [00:16<00:00,  1.16s/it]
# Evaluating (49 / 100 EPOCHS) (loss=0.98986) (dice score=0.15763): 100%|██████| 8/8 [00:03<00:00,  2.56it/s]
# Training (50 / 100 EPOCHS) (loss=0.84948) (dice score=0.21027): 100%|██████| 14/14 [00:16<00:00,  1.16s/it]
# Evaluating (50 / 100 EPOCHS) (loss=0.52486) (dice score=0.25750): 100%|██████| 8/8 [00:03<00:00,  2.58it/s]
# Best record! [50] Test Loss: 0.698257, Dice score: 0.228049
# saved model
# Training (51 / 100 EPOCHS) (loss=0.97882) (dice score=0.19835): 100%|██████| 14/14 [00:16<00:00,  1.14s/it]
# Evaluating (51 / 100 EPOCHS) (loss=0.58885) (dice score=0.22700): 100%|██████| 8/8 [00:03<00:00,  2.61it/s]
# Training (52 / 100 EPOCHS) (loss=0.95951) (dice score=0.24086): 100%|██████| 14/14 [00:16<00:00,  1.15s/it]
# Evaluating (52 / 100 EPOCHS) (loss=0.98604) (dice score=0.20074): 100%|██████| 8/8 [00:03<00:00,  2.62it/s]
# Training (53 / 100 EPOCHS) (loss=0.81564) (dice score=0.21147): 100%|██████| 14/14 [00:15<00:00,  1.14s/it]
# Evaluating (53 / 100 EPOCHS) (loss=0.98875) (dice score=0.19195): 100%|██████| 8/8 [00:03<00:00,  2.62it/s]
# Training (54 / 100 EPOCHS) (loss=0.71431) (dice score=0.31305): 100%|██████| 14/14 [00:15<00:00,  1.14s/it]
# Evaluating (54 / 100 EPOCHS) (loss=0.40365) (dice score=0.33466): 100%|██████| 8/8 [00:03<00:00,  2.59it/s]
# Best record! [54] Test Loss: 0.668502, Dice score: 0.316971
# saved model
# Training (55 / 100 EPOCHS) (loss=0.72913) (dice score=0.27759): 100%|██████| 14/14 [00:16<00:00,  1.16s/it]
# Evaluating (55 / 100 EPOCHS) (loss=0.44303) (dice score=0.33149): 100%|██████| 8/8 [00:03<00:00,  2.50it/s]
# Best record! [55] Test Loss: 0.541340, Dice score: 0.307354
# saved model
# Training (56 / 100 EPOCHS) (loss=0.68081) (dice score=0.31401): 100%|██████| 14/14 [00:17<00:00,  1.25s/it]
# Evaluating (56 / 100 EPOCHS) (loss=0.98460) (dice score=0.28641): 100%|██████| 8/8 [00:03<00:00,  2.49it/s]
# Training (57 / 100 EPOCHS) (loss=0.64171) (dice score=0.34047): 100%|██████| 14/14 [00:17<00:00,  1.24s/it]
# Evaluating (57 / 100 EPOCHS) (loss=0.98610) (dice score=0.31419): 100%|██████| 8/8 [00:03<00:00,  2.39it/s]
# Training (58 / 100 EPOCHS) (loss=0.67757) (dice score=0.33375): 100%|██████| 14/14 [00:16<00:00,  1.19s/it]
# Evaluating (58 / 100 EPOCHS) (loss=0.98646) (dice score=0.29242): 100%|██████| 8/8 [00:03<00:00,  2.48it/s]
# Training (59 / 100 EPOCHS) (loss=0.79126) (dice score=0.36772): 100%|██████| 14/14 [00:17<00:00,  1.22s/it]
# Evaluating (59 / 100 EPOCHS) (loss=0.38156) (dice score=0.34626): 100%|██████| 8/8 [00:03<00:00,  2.40it/s]
# Training (60 / 100 EPOCHS) (loss=0.57737) (dice score=0.30462): 100%|██████| 14/14 [00:17<00:00,  1.25s/it]
# Evaluating (60 / 100 EPOCHS) (loss=0.46797) (dice score=0.32160): 100%|██████| 8/8 [00:03<00:00,  2.50it/s]
# Training (61 / 100 EPOCHS) (loss=0.59508) (dice score=0.34535): 100%|██████| 14/14 [00:17<00:00,  1.24s/it]
# Evaluating (61 / 100 EPOCHS) (loss=0.81206) (dice score=0.34512): 100%|██████| 8/8 [00:03<00:00,  2.43it/s]
# Training (62 / 100 EPOCHS) (loss=0.62051) (dice score=0.39601): 100%|██████| 14/14 [00:17<00:00,  1.22s/it]
# Evaluating (62 / 100 EPOCHS) (loss=0.96588) (dice score=0.35192): 100%|██████| 8/8 [00:03<00:00,  2.41it/s]
# Training (63 / 100 EPOCHS) (loss=0.58934) (dice score=0.37560): 100%|██████| 14/14 [00:17<00:00,  1.25s/it]
# Evaluating (63 / 100 EPOCHS) (loss=0.97908) (dice score=0.33520): 100%|██████| 8/8 [00:03<00:00,  2.43it/s]
# Training (64 / 100 EPOCHS) (loss=0.61404) (dice score=0.38149): 100%|██████| 14/14 [00:17<00:00,  1.23s/it]
# Evaluating (64 / 100 EPOCHS) (loss=0.35125) (dice score=0.38879): 100%|██████| 8/8 [00:03<00:00,  2.50it/s]
# Training (65 / 100 EPOCHS) (loss=0.63443) (dice score=0.35051): 100%|██████| 14/14 [00:17<00:00,  1.24s/it]
# Evaluating (65 / 100 EPOCHS) (loss=0.27760) (dice score=0.34901): 100%|██████| 8/8 [00:03<00:00,  2.43it/s]
# Training (66 / 100 EPOCHS) (loss=0.97437) (dice score=0.30529): 100%|██████| 14/14 [00:17<00:00,  1.24s/it]
# Evaluating (66 / 100 EPOCHS) (loss=0.98226) (dice score=0.28933): 100%|██████| 8/8 [00:03<00:00,  2.49it/s]
# Training (67 / 100 EPOCHS) (loss=0.70323) (dice score=0.29486): 100%|██████| 14/14 [00:17<00:00,  1.27s/it]
# Evaluating (67 / 100 EPOCHS) (loss=0.98259) (dice score=0.26478): 100%|██████| 8/8 [00:03<00:00,  2.38it/s]
# Training (68 / 100 EPOCHS) (loss=0.68950) (dice score=0.35045): 100%|██████| 14/14 [00:17<00:00,  1.22s/it]
# Evaluating (68 / 100 EPOCHS) (loss=0.26879) (dice score=0.36067): 100%|██████| 8/8 [00:03<00:00,  2.46it/s]
# Training (69 / 100 EPOCHS) (loss=0.56859) (dice score=0.38385): 100%|██████| 14/14 [00:17<00:00,  1.23s/it]
# Evaluating (69 / 100 EPOCHS) (loss=0.47521) (dice score=0.38172): 100%|██████| 8/8 [00:03<00:00,  2.42it/s]
# Training (70 / 100 EPOCHS) (loss=0.58777) (dice score=0.39515): 100%|██████| 14/14 [00:17<00:00,  1.25s/it]
# Evaluating (70 / 100 EPOCHS) (loss=0.97328) (dice score=0.35632): 100%|██████| 8/8 [00:03<00:00,  2.49it/s]
# Training (71 / 100 EPOCHS) (loss=0.59109) (dice score=0.39469): 100%|██████| 14/14 [00:17<00:00,  1.25s/it]
# Evaluating (71 / 100 EPOCHS) (loss=0.98556) (dice score=0.33657): 100%|██████| 8/8 [00:03<00:00,  2.45it/s]
# Training (72 / 100 EPOCHS) (loss=0.59382) (dice score=0.41846): 100%|██████| 14/14 [00:17<00:00,  1.23s/it]
# Evaluating (72 / 100 EPOCHS) (loss=0.95375) (dice score=0.36411): 100%|██████| 8/8 [00:03<00:00,  2.43it/s]
# Training (73 / 100 EPOCHS) (loss=0.60484) (dice score=0.37643): 100%|██████| 14/14 [00:17<00:00,  1.22s/it]
# Evaluating (73 / 100 EPOCHS) (loss=0.72189) (dice score=0.35877): 100%|██████| 8/8 [00:03<00:00,  2.43it/s]
# Training (74 / 100 EPOCHS) (loss=0.57945) (dice score=0.42588): 100%|██████| 14/14 [00:17<00:00,  1.27s/it]
# Evaluating (74 / 100 EPOCHS) (loss=0.29124) (dice score=0.39182): 100%|██████| 8/8 [00:03<00:00,  2.41it/s]
# Training (75 / 100 EPOCHS) (loss=0.53772) (dice score=0.39542): 100%|██████| 14/14 [00:17<00:00,  1.24s/it]
# Evaluating (75 / 100 EPOCHS) (loss=0.95442) (dice score=0.35818): 100%|██████| 8/8 [00:03<00:00,  2.41it/s]
# Training (76 / 100 EPOCHS) (loss=0.57539) (dice score=0.37762): 100%|██████| 14/14 [00:17<00:00,  1.24s/it]
# Evaluating (76 / 100 EPOCHS) (loss=0.92874) (dice score=0.35956): 100%|██████| 8/8 [00:03<00:00,  2.45it/s]
# Training (77 / 100 EPOCHS) (loss=0.55816) (dice score=0.40695): 100%|██████| 14/14 [00:17<00:00,  1.25s/it]
# Evaluating (77 / 100 EPOCHS) (loss=0.67478) (dice score=0.39176): 100%|██████| 8/8 [00:03<00:00,  2.48it/s]
# Training (78 / 100 EPOCHS) (loss=0.59896) (dice score=0.41211): 100%|██████| 14/14 [00:17<00:00,  1.23s/it]
# Evaluating (78 / 100 EPOCHS) (loss=0.29548) (dice score=0.40997): 100%|██████| 8/8 [00:03<00:00,  2.47it/s]
# Training (79 / 100 EPOCHS) (loss=0.58864) (dice score=0.43588): 100%|██████| 14/14 [00:17<00:00,  1.23s/it]
# Evaluating (79 / 100 EPOCHS) (loss=0.59988) (dice score=0.42873): 100%|██████| 8/8 [00:03<00:00,  2.51it/s]
# Training (80 / 100 EPOCHS) (loss=0.54083) (dice score=0.40810): 100%|██████| 14/14 [00:17<00:00,  1.27s/it]
# Evaluating (80 / 100 EPOCHS) (loss=0.35972) (dice score=0.40432): 100%|██████| 8/8 [00:03<00:00,  2.39it/s]
# Training (81 / 100 EPOCHS) (loss=0.57079) (dice score=0.44316): 100%|██████| 14/14 [00:17<00:00,  1.23s/it]
# Evaluating (81 / 100 EPOCHS) (loss=0.33893) (dice score=0.42996): 100%|██████| 8/8 [00:03<00:00,  2.48it/s]
# Training (82 / 100 EPOCHS) (loss=0.57018) (dice score=0.44050): 100%|██████| 14/14 [00:17<00:00,  1.24s/it]
# Evaluating (82 / 100 EPOCHS) (loss=0.34589) (dice score=0.41895): 100%|██████| 8/8 [00:03<00:00,  2.45it/s]
# Training (83 / 100 EPOCHS) (loss=0.56084) (dice score=0.44284): 100%|██████| 14/14 [00:17<00:00,  1.24s/it]
# Evaluating (83 / 100 EPOCHS) (loss=0.94912) (dice score=0.39155): 100%|██████| 8/8 [00:03<00:00,  2.45it/s]
# Training (84 / 100 EPOCHS) (loss=0.55776) (dice score=0.42778): 100%|██████| 14/14 [00:16<00:00,  1.21s/it]
# Evaluating (84 / 100 EPOCHS) (loss=0.25762) (dice score=0.43494): 100%|██████| 8/8 [00:03<00:00,  2.50it/s]
# Training (85 / 100 EPOCHS) (loss=0.59959) (dice score=0.38960): 100%|██████| 14/14 [00:17<00:00,  1.25s/it]
# Evaluating (85 / 100 EPOCHS) (loss=0.28815) (dice score=0.38964): 100%|██████| 8/8 [00:03<00:00,  2.43it/s]
# Training (86 / 100 EPOCHS) (loss=0.57029) (dice score=0.43998): 100%|██████| 14/14 [00:17<00:00,  1.25s/it]
# Evaluating (86 / 100 EPOCHS) (loss=0.32371) (dice score=0.42274): 100%|██████| 8/8 [00:03<00:00,  2.40it/s]
# Training (87 / 100 EPOCHS) (loss=0.56028) (dice score=0.42303): 100%|██████| 14/14 [00:17<00:00,  1.24s/it]
# Evaluating (87 / 100 EPOCHS) (loss=0.25859) (dice score=0.43813): 100%|██████| 8/8 [00:03<00:00,  2.42it/s]
# Best record! [87] Test Loss: 0.535932, Dice score: 0.419827
# saved model
# Training (88 / 100 EPOCHS) (loss=0.58804) (dice score=0.38736): 100%|██████| 14/14 [00:17<00:00,  1.25s/it]
# Evaluating (88 / 100 EPOCHS) (loss=0.90114) (dice score=0.36626): 100%|██████| 8/8 [00:03<00:00,  2.39it/s]
# Training (89 / 100 EPOCHS) (loss=0.55511) (dice score=0.43873): 100%|██████| 14/14 [00:17<00:00,  1.24s/it]
# Evaluating (89 / 100 EPOCHS) (loss=0.97910) (dice score=0.37024): 100%|██████| 8/8 [00:03<00:00,  2.41it/s]
# Training (90 / 100 EPOCHS) (loss=0.57077) (dice score=0.41395): 100%|██████| 14/14 [00:17<00:00,  1.25s/it]
# Evaluating (90 / 100 EPOCHS) (loss=0.96920) (dice score=0.35934): 100%|██████| 8/8 [00:03<00:00,  2.44it/s]
# Training (91 / 100 EPOCHS) (loss=0.54884) (dice score=0.42982): 100%|██████| 14/14 [00:17<00:00,  1.23s/it]
# Evaluating (91 / 100 EPOCHS) (loss=0.85863) (dice score=0.40067): 100%|██████| 8/8 [00:03<00:00,  2.41it/s]
# Training (92 / 100 EPOCHS) (loss=0.53517) (dice score=0.44352): 100%|██████| 14/14 [00:16<00:00,  1.21s/it]
# Evaluating (92 / 100 EPOCHS) (loss=0.83911) (dice score=0.41778): 100%|██████| 8/8 [00:03<00:00,  2.46it/s]
# Training (93 / 100 EPOCHS) (loss=0.65575) (dice score=0.42305): 100%|██████| 14/14 [00:17<00:00,  1.22s/it]
# Evaluating (93 / 100 EPOCHS) (loss=0.31884) (dice score=0.42795): 100%|██████| 8/8 [00:03<00:00,  2.41it/s]
# Training (94 / 100 EPOCHS) (loss=0.57306) (dice score=0.39152): 100%|██████| 14/14 [00:17<00:00,  1.23s/it]
# Evaluating (94 / 100 EPOCHS) (loss=0.27079) (dice score=0.39853): 100%|██████| 8/8 [00:03<00:00,  2.45it/s]
# Training (95 / 100 EPOCHS) (loss=0.55617) (dice score=0.45265): 100%|██████| 14/14 [00:17<00:00,  1.23s/it]
# Evaluating (95 / 100 EPOCHS) (loss=0.26220) (dice score=0.42936): 100%|██████| 8/8 [00:03<00:00,  2.40it/s]
# Training (96 / 100 EPOCHS) (loss=0.56732) (dice score=0.45587): 100%|██████| 14/14 [00:17<00:00,  1.23s/it]
# Evaluating (96 / 100 EPOCHS) (loss=0.20904) (dice score=0.45571): 100%|██████| 8/8 [00:03<00:00,  2.43it/s]
# Training (97 / 100 EPOCHS) (loss=0.57057) (dice score=0.45585): 100%|██████| 14/14 [00:17<00:00,  1.23s/it]
# Evaluating (97 / 100 EPOCHS) (loss=0.28759) (dice score=0.43887): 100%|██████| 8/8 [00:03<00:00,  2.50it/s]
# Training (98 / 100 EPOCHS) (loss=0.55899) (dice score=0.42351): 100%|██████| 14/14 [00:17<00:00,  1.24s/it]
# Evaluating (98 / 100 EPOCHS) (loss=0.66230) (dice score=0.40854): 100%|██████| 8/8 [00:03<00:00,  2.45it/s]
# Training (99 / 100 EPOCHS) (loss=0.56239) (dice score=0.41847): 100%|██████| 14/14 [00:17<00:00,  1.25s/it]
# Evaluating (99 / 100 EPOCHS) (loss=0.92970) (dice score=0.39044): 100%|██████| 8/8 [00:03<00:00,  2.38it/s]
# Training (100 / 100 EPOCHS) (loss=0.56301) (dice score=0.37610): 100%|█████| 14/14 [00:17<00:00,  1.23s/it]
# Evaluating (100 / 100 EPOCHS) (loss=0.98747) (dice score=0.32830): 100%|█████| 8/8 [00:03<00:00,  2.41it/s]

# %%
print(f"train completed, best_metric: {best_metric:.4f} at epoch: {best_epoch}")
# Out:
# train completed, best_metric: 0.5359 at epoch: 87

# %% [markdown]
# 11. learning curve

# %%
epochs = [i for i in range(len(losses['train']))]
train_loss = losses['train']
val_loss = losses['val']
train_dice = dice_scores['train']
val_dice = dice_scores['val']

fig , ax = plt.subplots(1,2)
fig.set_size_inches(12,6)

ax[0].plot(epochs , train_loss , 'g-o' , label = 'Training Loss')
ax[0].plot(epochs , val_loss , 'r-o' , label = 'Validation Loss')
ax[0].set_title('Training & Validation Loss')
ax[0].legend()
ax[0].set_xlabel("Epochs")
ax[0].set_ylabel("Loss")

ax[1].plot(epochs , train_dice , 'go-' , label = 'Training Dice score')
ax[1].plot(epochs , val_dice , 'ro-' , label = 'Validation Dice score')
ax[1].set_title('Training & Validation Dice score')
ax[1].legend()
ax[1].set_xlabel("Epochs")
ax[1].set_ylabel("Dice score")

plt.show()

# %% [markdown]
# 12. visualize the result

# %%
pred_dict = {'input':[], 'target':[], 'output':[]}

if MODEL_SAVE:
    model.load_state_dict(torch.load(os.path.join(MODEL_SAVE_PATH, model_name)))

model.to('cpu')
model.eval()
with torch.no_grad():
    for i, data in enumerate(test_loader):
        img, target = data["image"].cpu(), data["label"].cpu()

        output = model(img).detach().cpu()
        output = torch.argmax(output, dim=1)
        
        pred_dict['input'].append(img)
        pred_dict['target'].append(target)
        pred_dict['output'].append(output)
        
        if i > 10:
            break

# %%
ncols, nrows = 10, 3*3
interval = int(IMAGE_SIZE[-1]//(ncols*nrows/3))
fig, axes = plt.subplots(ncols=ncols, nrows=nrows, figsize=(ncols,nrows))
cnt1, cnt2, cnt3 = 0, 0, 0
for i in range(nrows):
    for j in range(ncols):
        if i%3 == 0:
            axes[i,j].imshow(pred_dict['input'][0][0,0,:,:,cnt1], cmap='gray')
            cnt1+=interval
        elif i%3 == 1:
            axes[i,j].imshow(pred_dict['target'][0][0,0,:,:,cnt2], cmap='gray')
            cnt2+=interval
        else:
            axes[i,j].imshow(pred_dict['output'][0][0,:,:,cnt3], cmap='gray')
            cnt3+=interval
        axes[i,j].axis('off')
plt.subplots_adjust(wspace=0, hspace=0, left=0, right=1, bottom=0, top=1)
plt.show()
